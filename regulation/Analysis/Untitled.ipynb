# %%
# import dependencies
from path import Path
import pandas as pd
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
# Import dataset & store into dataframe
merged_covid_df = pd.read_csv("../Resources/merged_covid_FINAL.csv",index_col="location")
merged_covid_df
# Out:
#          primary_key_reaction date_updated iso_code      continent  \
# location
# Aruba           ABW2020-03-13   2020-03-13      ABW  North America
# Aruba           ABW2020-03-19   2020-03-19      ABW  North America
# Aruba           ABW2020-03-20   2020-03-20      ABW  North America
# Aruba           ABW2020-03-21   2020-03-21      ABW  North America
# Aruba           ABW2020-03-22   2020-03-22      ABW  North America
# ...                       ...          ...      ...            ...
# Zimbabwe        ZWE2020-08-27   2020-08-27      ZWE         Africa
# Zimbabwe        ZWE2020-08-28   2020-08-28      ZWE         Africa
# Zimbabwe        ZWE2020-08-29   2020-08-29      ZWE         Africa
# Zimbabwe        ZWE2020-08-30   2020-08-30      ZWE         Africa
# Zimbabwe        ZWE2020-08-31   2020-08-31      ZWE         Africa
#
#           population  population_density  median_age  new_cases  \
# location
# Aruba       106766.0             584.800        41.2        2.0
# ...

# %%
#continent_location_age_df = merged_covid_df[["continent","location","median_age"]]
#continent_location_age_df

# %%
NA_Africa_df = merged_covid_df.loc[["Canada","United States", "Nigeria","Zimbabwe"]] 
NA_Africa_df
# Out:
#          primary_key_reaction date_updated iso_code      continent  \
# location
# Canada          CAN2020-01-01   2020-01-01      CAN  North America
# Canada          CAN2020-01-02   2020-01-02      CAN  North America
# Canada          CAN2020-01-03   2020-01-03      CAN  North America
# Canada          CAN2020-01-04   2020-01-04      CAN  North America
# Canada          CAN2020-01-05   2020-01-05      CAN  North America
# ...                       ...          ...      ...            ...
# Zimbabwe        ZWE2020-08-27   2020-08-27      ZWE         Africa
# Zimbabwe        ZWE2020-08-28   2020-08-28      ZWE         Africa
# Zimbabwe        ZWE2020-08-29   2020-08-29      ZWE         Africa
# Zimbabwe        ZWE2020-08-30   2020-08-30      ZWE         Africa
# Zimbabwe        ZWE2020-08-31   2020-08-31      ZWE         Africa
#
#           population  population_density  median_age  new_cases  \
# location
# Canada    37742157.0               4.037        41.4        0.0
# ...

# %%
Comparison_df= NA_Africa_df[["date_updated","median_age", "total_cases_updated","total_deaths_updated","population_density"]]
Comparison_df
# Out:
#          date_updated  median_age  total_cases_updated  total_deaths_updated  \
# location
# Canada     2020-01-01        41.4                  0.0                   0.0
# Canada     2020-01-02        41.4                  0.0                   0.0
# Canada     2020-01-03        41.4                  0.0                   0.0
# Canada     2020-01-04        41.4                  0.0                   0.0
# Canada     2020-01-05        41.4                  0.0                   0.0
# ...               ...         ...                  ...                   ...
# Zimbabwe   2020-08-27        19.6               6251.0                 179.0
# Zimbabwe   2020-08-28        19.6               6292.0                 189.0
# Zimbabwe   2020-08-29        19.6               6388.0                 195.0
# Zimbabwe   2020-08-30        19.6               6406.0                 196.0
# Zimbabwe   2020-08-31        19.6               6412.0                 196.0
#
#           population_density
# ...

# %%
Merged_df=Comparison_df.reset_index()
Merged_df
# Out:
#      location date_updated  median_age  total_cases_updated  \
# 0      Canada   2020-01-01        41.4                  0.0
# 1      Canada   2020-01-02        41.4                  0.0
# 2      Canada   2020-01-03        41.4                  0.0
# 3      Canada   2020-01-04        41.4                  0.0
# 4      Canada   2020-01-05        41.4                  0.0
# ..        ...          ...         ...                  ...
# 891  Zimbabwe   2020-08-27        19.6               6251.0
# 892  Zimbabwe   2020-08-28        19.6               6292.0
# 893  Zimbabwe   2020-08-29        19.6               6388.0
# 894  Zimbabwe   2020-08-30        19.6               6406.0
# 895  Zimbabwe   2020-08-31        19.6               6412.0
#
#      total_deaths_updated  population_density
# 0                     0.0               4.037
# 1                     0.0               4.037
# 2                     0.0               4.037
# 3                     0.0               4.037
# ...

# %%
# Set index to datetime

# index=pd.DatetimeIndex(index))
Merged_df.index = pd.DatetimeIndex(Merged_df['date_updated'])
Merged_df
# Out:
#               location date_updated  median_age  total_cases_updated  \
# date_updated
# 2020-01-01      Canada   2020-01-01        41.4                  0.0
# 2020-01-02      Canada   2020-01-02        41.4                  0.0
# 2020-01-03      Canada   2020-01-03        41.4                  0.0
# 2020-01-04      Canada   2020-01-04        41.4                  0.0
# 2020-01-05      Canada   2020-01-05        41.4                  0.0
# ...                ...          ...         ...                  ...
# 2020-08-27    Zimbabwe   2020-08-27        19.6               6251.0
# 2020-08-28    Zimbabwe   2020-08-28        19.6               6292.0
# 2020-08-29    Zimbabwe   2020-08-29        19.6               6388.0
# 2020-08-30    Zimbabwe   2020-08-30        19.6               6406.0
# 2020-08-31    Zimbabwe   2020-08-31        19.6               6412.0
#
#               total_deaths_updated  population_density
# date_updated
# ...

# %%
# Check index to ensure it is set to DatetimeIndex
Merged_df.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-08-22', '2020-08-23', '2020-08-24', '2020-08-25',
#                '2020-08-26', '2020-08-27', '2020-08-28', '2020-08-29',
#                '2020-08-30', '2020-08-31'],
#               dtype='datetime64[ns]', name='date_updated', length=896, freq=None)

# %%
## Use Copy() function to create new Data frame
New_merged_df = Merged_df[["location","median_age"]].copy()
New_merged_df
# Out:
#               location  median_age
# date_updated
# 2020-01-01      Canada        41.4
# 2020-01-02      Canada        41.4
# 2020-01-03      Canada        41.4
# 2020-01-04      Canada        41.4
# 2020-01-05      Canada        41.4
# ...                ...         ...
# 2020-08-27    Zimbabwe        19.6
# 2020-08-28    Zimbabwe        19.6
# 2020-08-29    Zimbabwe        19.6
# 2020-08-30    Zimbabwe        19.6
# 2020-08-31    Zimbabwe        19.6
#
# [896 rows x 2 columns]

# %%
New_merged_df.max()
# Out:
# location      Zimbabwe
# median_age        41.4
# dtype: object

# %%
updated_df= New_merged_df.reset_index()
updated_df
# Out:
#     date_updated  location  median_age
# 0     2020-01-01    Canada        41.4
# 1     2020-01-02    Canada        41.4
# 2     2020-01-03    Canada        41.4
# 3     2020-01-04    Canada        41.4
# 4     2020-01-05    Canada        41.4
# ..           ...       ...         ...
# 891   2020-08-27  Zimbabwe        19.6
# 892   2020-08-28  Zimbabwe        19.6
# 893   2020-08-29  Zimbabwe        19.6
# 894   2020-08-30  Zimbabwe        19.6
# 895   2020-08-31  Zimbabwe        19.6
#
# [896 rows x 3 columns]

# %%
# Use info () to check confirm index of new data frame
New_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 896 entries, 2020-01-01 to 2020-08-31
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    896 non-null    object
#  1   median_age  896 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 21.0+ KB

# %%
location_age = pd.DataFrame(merged_covid_df.groupby(["location"]).mean()["median_age"]).reset_index()
location_age
# Out:
#         location  median_age
# 0    Afghanistan        18.6
# 1        Albania        38.0
# 2        Algeria        29.1
# 3         Angola        16.8
# 4      Argentina        31.9
# ..           ...         ...
# 159    Venezuela        29.0
# 160      Vietnam        32.6
# 161        Yemen        20.3
# 162       Zambia        17.7
# 163     Zimbabwe        19.6
#
# [164 rows x 2 columns]

# %%
# Create the plot.
plt.bar("median_age", "location", color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()
