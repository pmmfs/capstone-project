# %%
# Import the dependencies

import numpy as np
import pandas as pd
import re

from matplotlib import pyplot as plt
from sklearn.metrics import r2_score

from datetime import timedelta,datetime

import sys
from path import Path

# imports for database connection
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import create_engine, func

# import these to view table column headers & rows
from sqlalchemy.orm import sessionmaker
from sqlalchemy import select

# %%
# Import the user-defined ml class

class_path = Path("../classes/pmmfs_ml")
sys.path.append(class_path)
from ml import ml

# %%
# reflect an existing database into a new model (creates base class for automap schema)
Base = automap_base()

# %%
engine = create_engine("sqlite:///Resources/covid_db.db")

# %%
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# ['covid_stats', 'government_regulation']

# %%
# save references to each table
covid_stats = Base.classes.covid_stats
government_regulation = Base.classes.government_regulation

# %%
# Create session (link) from Python to the database
session = sessionmaker(bind=engine)()

# %%
# View table column headers & rows - covid_stats
covid_stats_table = select('*').select_from(covid_stats)
covid_stats_result = session.execute(covid_stats_table).fetchall()

# %%
# View table column headers & rows - government_regulation
government_regulation_table = select('*').select_from(government_regulation)
government_regulation_result = session.execute(government_regulation_table).fetchall()

# %%
# Merge covid_stats_table with government regulation_table
joined = session.query(covid_stats.primary_key_reaction,\
                        covid_stats.date_updated,\
                        covid_stats.iso_code,\
                        covid_stats.continent,\
                        covid_stats.location,\
                        covid_stats.population,\
                        covid_stats.population_density,\
                        covid_stats.median_age,\
                        covid_stats.new_cases,\
                        covid_stats.percentage_of_Pop_New_Cases,\
                        covid_stats.new_deaths,\
                        covid_stats.percentage_of_Pop_New_Deaths,\
                        covid_stats.new_tests,\
                        covid_stats.percentage_of_Pop_New_Tests,\
                        covid_stats.total_cases_updated,\
                        covid_stats.percentage_of_Pop_Total_Cases,\
                        covid_stats.total_deaths_updated,\
                        covid_stats.percentage_of_Pop_Total_Deaths,\
                        covid_stats.total_tests_updated,\
                        covid_stats.percentage_of_Pop_Total_Tests,\
                        government_regulation.primary_key_response,\
                        government_regulation.Date_updated,\
                        government_regulation.CountryName,\
                        government_regulation.CountryCode,\
                        government_regulation.C1_School_closing,\
                        government_regulation.C1_Flag,\
                        government_regulation.C2_Workplace_closing,\
                        government_regulation.C2_Flag,\
                        government_regulation.C3_Cancel_public_events,\
                        government_regulation.C3_Flag,\
                        government_regulation.C4_Restrictions_on_gatherings,\
                        government_regulation.C4_Flag,\
                        government_regulation.C5_Close_public_transport,\
                        government_regulation.C5_Flag,\
                        government_regulation.C6_Stay_at_home_requirements,\
                        government_regulation.C6_Flag,\
                        government_regulation.C7_Restrictions_on_internal_movement,\
                        government_regulation.C7_Flag,\
                        government_regulation.C8_International_travel_controls,\
                        government_regulation.E1_Income_support,\
                        government_regulation.E1_Flag,\
                        government_regulation.H1_Public_information_campaigns,\
                        government_regulation.H1_Flag,\
                        government_regulation.StringencyIndex_updated,\
                        government_regulation.percentage_change_stringency,\
                        government_regulation.StringencyLegacyIndex_updated,\
                        government_regulation.GovernmentResponseIndex_updated,\
                        government_regulation.percentage_change_GovernmentResponse,\
                        government_regulation.ContainmentHealthIndex_updated,\
                        government_regulation.percentage_change_ContainmentHealth,\
                        government_regulation.EconomicSupportIndex_updated,\
                        government_regulation.percentage_change_EconomicSupport)\
        .join(government_regulation,government_regulation.primary_key_response == covid_stats.primary_key_reaction)

# save the query results as a Pandas DataFrame and set the index
cleaned_df = pd.DataFrame(joined, columns=[ 'primary_key_reaction',
                                    'date_updated',
                                    'iso_code',
                                    'continent',
                                    'location',
                                    'population',
                                    'population_density',
                                    'median_age',
                                    'new_cases',
                                    'percentage_of_Pop_New_Cases',
                                    'new_deaths',
                                    'percentage_of_Pop_New_Deaths',
                                    'new_tests',
                                    'percentage_of_Pop_New_Tests',
                                    'total_cases_updated',
                                    'percentage_of_Pop_Total_Cases',
                                    'total_deaths_updated',
                                    'percentage_of_Pop_Total_Deaths',
                                    'total_tests_updated',
                                    'percentage_of_Pop_Total_Tests',
                                    'primary_key_response',
                                    'Date_updated',
                                    'CountryName',
                                    'CountryCode',
                                    'C1_School_closing',
                                    'C1_Flag',
                                    'C2_Workplace_closing',
                                    'C2_Flag',
                                    'C3_Cancel_public_events',
                                    'C3_Flag',
                                    'C4_Restrictions_on_gatherings',
                                    'C4_Flag',
                                    'C5_Close_public_transport',
                                    'C5_Flag',
                                    'C6_Stay_at_home_requirements',
                                    'C6_Flag',
                                    'C7_Restrictions_on_internal_movement',
                                    'C7_Flag',
                                    'C8_International_travel_controls',
                                    'E1_Income_support',
                                    'E1_Flag',
                                    'H1_Public_information_campaigns',
                                    'H1_Flag',
                                    'StringencyIndex_updated',
                                    'percentage_change_stringency',
                                    'StringencyLegacyIndex_updated',
                                    'GovernmentResponseIndex_updated',
                                    'percentage_change_GovernmentResponse',
                                    'ContainmentHealthIndex_updated',
                                    'percentage_change_ContainmentHealth',
                                    'EconomicSupportIndex_updated',
                                    'percentage_change_EconomicSupport'
                                ])

# %%
# Get the country codes 

iso_codes = cleaned_df["iso_code"].unique()

# %%
# This function converts a date string of the format YYYYMMDD to YYYY-MM-DD

def formatDate(dt):
    d_str = str(dt)
    year = d_str[0:4]
    month = d_str[4:6]
    day = d_str[6:8]
    dt_str = year + "-" + month + "-" + day
     
    return dt_str

# %%
# Create four dataframes, one for each feature set to be explored for predicting future total cases and total deaths

df = cleaned_df[['date_updated','iso_code','population','population_density','median_age','C1_School_closing','C2_Workplace_closing','C3_Cancel_public_events','C4_Restrictions_on_gatherings','C5_Close_public_transport','C6_Stay_at_home_requirements','C7_Restrictions_on_internal_movement','C8_International_travel_controls','total_cases_updated','total_deaths_updated']]

# %%
# The following function creates a dataframe for each individual iso_code (country code), which contains the 
# following information:
# - date, iso_code, future date

# It returns a dictionary of the country codes dataframes and a list of the iso_codes used as dictionary key values

# Input: 
# df - A list of dataframes

# Returns:
# - A countries dictionary, each element of which contains future date dictionaries, each of which has 
# three columns: data, iso_code, and future date
# - A iso_codes list contain a unique list of all the country codes

def get_iso_dicts(df):
    
    # Get a lost of the iso_codes
    #  iso_codes = df["iso_code"].unique()
    # iso_codes = ["CAN","GBR","USA"]
    
    # Initialize the country codes dictionary
    iso_dicts = {}
    
    # Iterate through the iso_cides
    for code in iso_codes:
        
        # Create a dictionary for the current iso_code
        iso_dicts[code] = {}
        
        # For each value of day in the future list (30,45,60, and 75)
        for day in future:
            
            # Create the future date column name
            date_col = "_".join(["date_updated",day])
            
            # Copy the date and iso_code columns to a new dataframe, df_iso
            df_iso = cleaned_df[cleaned_df["iso_code"]==code][["date_updated","iso_code"]]
            
            # Set the future date column to the current date + the current value of day
            df_iso[date_col] = pd.to_datetime(df_iso["date_updated"]) + timedelta(days=int(day))
            
            # Set the type of the future date column to str so that it can be used in merge operations
            df_iso[date_col] = df_iso[date_col].astype(str)

            # Add the dataframe to the iso_dicts country dictionaries 
            iso_dicts[code][day] = df_iso
                    
            if code == "CAN":
                can_df = df_iso.copy()
                
    # Return the country dataframes and the country codes        
    return iso_dicts, iso_codes

# %%
# This function groups all the country-day dataframe by the number of days into the future (30,45,60,75) into
# a list of four dataframes
#
# Input:
# iso_codes - country codes list
# iso_dicts - country-future-dates dictionaries
#
# Returns:
# A list of dataframes, one for each of the future days being considered
def get_cum_days(*iso_codes, **iso_dicts):
    
    # Initialize the days dataframe list
    days = []

    # For each day value in futures ('30','45','60','75')
    for day in future:
        
        # Create a new cumulative dataframe
        cum_df = pd.DataFrame()
        
        # For each iso code (country code)
        for code in iso_codes:
            
            # Append the dataframe corresponding to the country and the future days to the current cumulative dataframe
            cum_df = cum_df.append(iso_dicts[code][day])

        # Add the current cumulative dataframe to the days dataframe list
        days.append(cum_df.reset_index(drop=True))
    
    return days

# %%
# This function creates the future total cases and future total deaths columns by left joining the days dataframes
# with the original dataframe on the future date, the current date, and the iso_code columns.

# Input:
# days - list of future date dataframe

# Return:
# m_days - list of dataframes containing future total deaths and future total cases

def get_amended_days(*days):
        
    # Initialize the amended days dataframe list
    m_days = []
    
    # Iterate through the values in the future list ['30','45','60','75']
    for i,day in enumerate(future):
        
        # Merge the current days dataframe with the original dataframe and append it to m_days
        m_days.append(days[i].merge(cleaned_df,left_on=["date_updated_" + day,"iso_code"],right_on=["date_updated","iso_code"],how="left",suffixes=["","_" + day]))
        
        # Drop the index of the merged dataframe
        m_days[i] = m_days[i].reset_index(drop=True)
        
        # Choose the useful columns from the merged dataframe
        m_days[i] = m_days[i][["date_updated","iso_code","date_updated_" + day,"total_cases_updated","total_deaths_updated"]]
        
        # Rename the total_cases and total_deaths case to identify to which future period they belong
        m_days[i].rename(columns={"total_cases_updated":"total_cases_" + day,
                           "total_deaths_updated":"total_deaths_" + day},inplace=True)
        
    return m_days

# %%
# This function creates the list of day dataframes, one for each of the future periods under consideration. 
# The dataframes contain the following columns: date, iso_code, future_date, future total cases, future total deaths 

def get_days(df):
    
    # Get the country-days dicts and the country iso codes
    iso_dicts, iso_codes = get_iso_dicts(df)
    
    # Get the list of days dataframes for each of the future period lengths
    days = get_cum_days(*iso_codes, **iso_dicts)
        
    # Append to the list the future total deaths and the future total cases
    days = get_amended_days(*days)

    return days

# %%
# Earlier EDA has shown that, out of the researched neural network configurations, the following neural 
# network configuration produces the most accurate results

layers = { 
            "number_input_features": 0,   # number of input features will vary, value set elsewhere
            "n_layers": 4, 
            "l0":{"number_hidden_nodes":18,"activation_function":"relu"},
            "l1":{"number_hidden_nodes":9,"activation_function":"relu"},
            "l2":{"number_hidden_nodes":4,"activation_function":"relu"},
            "l3":{"number_hidden_nodes":1,"activation_function":"linear"}
        }

# %%
# Regression Analysis

can_df = None

# Initialize the future days list 
future = ["30"]

# Initialize the list of models
models = []

# For each of the feature lists under consideration
# Get the list of future days dataframes
days = get_days(df)

# For each of the targets, namely total_cases and total_deaths
for target in ["total_cases","total_deaths"]:

    print(f"{target} %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%>\n\n")

    # For each day in future ['30','45','60','75']
    for i,day in enumerate(future):

        print(f"\n\n>>>>>>>> {day} >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> ")

        # Get the features
        features = df.columns

        # Merge the feature dataframe with the day dataframe
        df_n = df.merge(days[i],on=["date_updated","iso_code"],how="left")
        # df_n.to_csv(f"Resources/Model-3-Days-{future[i]}.csv")

        # Remove the target columns from merged dataframe
        print(f"features3 = {features}")
        features = [f for f in features if re.search("_\d{2}$",f) == None]
        print(f"features4 = {features}")
        #print(f"features3: {features}")
        features = features[2:]  # Remove date and iso_code
        #print(f"features4: {features}")
        # Set the number of input features for the neural networks based on the current feature set
        layers["number_input_features"] = len(features)

        # Create an instance of the ml class to start machine learning
        md = ml(df=df_n,
                feature_set=features,
                test_size=0.05,
                title=f"{target} - {day} days out",
                target=target,
                period=day,
                **layers
               )

        # Train and test the machine learning mode over 100 epochs
        print("train_test")
        md.train_test(epochs=100)

        # Append the instance of the ml class into the models list
        models.append(md)
# Out:
# total_cases %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%>
#
#
#
#
# >>>>>>>> 30 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# features3 = Index(['date_updated', 'iso_code', 'population', 'population_density',
#        'median_age', 'C1_School_closing', 'C2_Workplace_closing',
#        'C3_Cancel_public_events', 'C4_Restrictions_on_gatherings',
#        'C5_Close_public_transport', 'C6_Stay_at_home_requirements',
#        'C7_Restrictions_on_internal_movement',
#        'C8_International_travel_controls', 'total_cases_updated',
#        'total_deaths_updated'],
#       dtype='object')
# features4 = ['date_updated', 'iso_code', 'population', 'population_density', 'median_age', 'C1_School_closing', 'C2_Workplace_closing', 'C3_Cancel_public_events', 'C4_Restrictions_on_gatherings', 'C5_Close_public_transport', 'C6_Stay_at_home_requirements', 'C7_Restrictions_on_internal_movement', 'C8_International_travel_controls', 'total_cases_updated', 'total_deaths_updated']
# train_test
#
#
#  Training and testing - 30 days ahead
#
#
# target_n = total_cases_30
#
# features = ['population', 'population_density', 'median_age', 'C1_School_closing', 'C2_Workplace_closing', 'C3_Cancel_public_events', 'C4_Restrictions_on_gatherings', 'C5_Close_public_transport', 'C6_Stay_at_home_requirements', 'C7_Restrictions_on_internal_movement', 'C8_International_travel_controls', 'total_cases_updated', 'total_deaths_updated']
# population
#
# population_density
#
# median_age
#
# C1_School_closing
#
# C2_Workplace_closing
#
# C3_Cancel_public_events
#
# C4_Restrictions_on_gatherings
#
# C5_Close_public_transport
#
# C6_Stay_at_home_requirements
#
# C7_Restrictions_on_internal_movement
#
# C8_International_travel_controls
#
# total_cases_updated
#
# total_deaths_updated
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 18)                252
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 171
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 40
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 468
# Trainable params: 468
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.1726 - mse: 0.1726
# Epoch 2/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0233 - mse: 0.0233
# Epoch 3/100
# 813/813 [==============================] - 4s 4ms/step - loss: 0.0172 - mse: 0.0172
# Epoch 4/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0142 - mse: 0.0142
# Epoch 5/100
# 813/813 [==============================] - 4s 5ms/step - loss: 0.0124 - mse: 0.0124
# Epoch 6/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0109 - mse: 0.0109
# Epoch 7/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0092 - mse: 0.0092
# Epoch 8/100
# 813/813 [==============================] - 4s 4ms/step - loss: 0.0078 - mse: 0.0078
# Epoch 9/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0078 - mse: 0.0078
# Epoch 10/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0065 - mse: 0.0065
# Epoch 11/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0067 - mse: 0.0067
# Epoch 12/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0055 - mse: 0.0055
# Epoch 13/100
# 813/813 [==============================] - 4s 5ms/step - loss: 0.0056 - mse: 0.0056
# Epoch 14/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0052 - mse: 0.0052
# Epoch 15/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0054 - mse: 0.0054
# Epoch 16/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0048 - mse: 0.0048
# Epoch 17/100
# 813/813 [==============================] - 4s 5ms/step - loss: 0.0048 - mse: 0.0048
# Epoch 18/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0049 - mse: 0.0049
# Epoch 19/100
# 813/813 [==============================] - 4s 5ms/step - loss: 0.0041 - mse: 0.0041
# Epoch 20/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0041 - mse: 0.0041
# Epoch 21/100
# 813/813 [==============================] - 4s 4ms/step - loss: 0.0040 - mse: 0.0040
# Epoch 22/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0039 - mse: 0.0039
# Epoch 23/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0039 - mse: 0.0039
# Epoch 24/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 25/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0040 - mse: 0.0040
# Epoch 26/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0040 - mse: 0.0040
# Epoch 27/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0033 - mse: 0.0033
# Epoch 28/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 29/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0040 - mse: 0.0040
# Epoch 30/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0036 - mse: 0.0036
# Epoch 31/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 32/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 33/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 34/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 35/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 36/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0029 - mse: 0.0029
# Epoch 37/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 38/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 39/100
# 813/813 [==============================] - 4s 4ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 40/100
# 813/813 [==============================] - 4s 5ms/step - loss: 0.0026 - mse: 0.0026
# Epoch 41/100
# 813/813 [==============================] - 4s 5ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 42/100
# 813/813 [==============================] - 4s 5ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 43/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0027 - mse: 0.0027
# Epoch 44/100
# 813/813 [==============================] - 4s 5ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 45/100
# 813/813 [==============================] - 4s 4ms/step - loss: 0.0028 - mse: 0.0028
# Epoch 46/100
# 813/813 [==============================] - 4s 5ms/step - loss: 0.0026 - mse: 0.0026
# Epoch 47/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0027 - mse: 0.0027
# Epoch 48/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0027 - mse: 0.0027
# Epoch 49/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0026 - mse: 0.0026
# Epoch 50/100
# 813/813 [==============================] - 4s 5ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 51/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 52/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0026 - mse: 0.0026
# Epoch 53/100
# 813/813 [==============================] - 4s 4ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 54/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 55/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 56/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0025 - mse: 0.0025
# Epoch 57/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 58/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 59/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0025 - mse: 0.0025
# Epoch 60/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 61/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0029 - mse: 0.0029
# Epoch 62/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 63/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 64/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 65/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 66/100
# 813/813 [==============================] - ETA: 0s - loss: 0.0020 - mse: 0.002 - 2s 3ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 67/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0025 - mse: 0.0025
# Epoch 68/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 69/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 70/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0025 - mse: 0.0025
# Epoch 71/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 72/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 73/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 74/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 75/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 76/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 77/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 78/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0027 - mse: 0.0027
# Epoch 79/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 80/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 81/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 82/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 83/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 84/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 85/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 86/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 87/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 88/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 89/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 90/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 91/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 92/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 93/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0027 - mse: 0.0027
# Epoch 94/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 95/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 96/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 97/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 98/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 99/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 100/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0020 - mse: 0.0020
# Training r2_score = 0.9983505140660962
# Testing  r2_score = 0.9981686071588125
# total_deaths %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%>
#
#
#
#
# >>>>>>>> 30 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# features3 = Index(['date_updated', 'iso_code', 'population', 'population_density',
#        'median_age', 'C1_School_closing', 'C2_Workplace_closing',
#        'C3_Cancel_public_events', 'C4_Restrictions_on_gatherings',
#        'C5_Close_public_transport', 'C6_Stay_at_home_requirements',
#        'C7_Restrictions_on_internal_movement',
#        'C8_International_travel_controls', 'total_cases_updated',
#        'total_deaths_updated'],
#       dtype='object')
# features4 = ['date_updated', 'iso_code', 'population', 'population_density', 'median_age', 'C1_School_closing', 'C2_Workplace_closing', 'C3_Cancel_public_events', 'C4_Restrictions_on_gatherings', 'C5_Close_public_transport', 'C6_Stay_at_home_requirements', 'C7_Restrictions_on_internal_movement', 'C8_International_travel_controls', 'total_cases_updated', 'total_deaths_updated']
# train_test
#
#
#  Training and testing - 30 days ahead
#
#
# target_n = total_deaths_30
#
# features = ['population', 'population_density', 'median_age', 'C1_School_closing', 'C2_Workplace_closing', 'C3_Cancel_public_events', 'C4_Restrictions_on_gatherings', 'C5_Close_public_transport', 'C6_Stay_at_home_requirements', 'C7_Restrictions_on_internal_movement', 'C8_International_travel_controls', 'total_cases_updated', 'total_deaths_updated']
# population
#
# population_density
#
# median_age
#
# C1_School_closing
#
# C2_Workplace_closing
#
# C3_Cancel_public_events
#
# C4_Restrictions_on_gatherings
#
# C5_Close_public_transport
#
# C6_Stay_at_home_requirements
#
# C7_Restrictions_on_internal_movement
#
# C8_International_travel_controls
#
# total_cases_updated
#
# total_deaths_updated
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 18)                252
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 171
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 40
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 468
# Trainable params: 468
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.2653 - mse: 0.2653
# Epoch 2/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0418 - mse: 0.0418
# Epoch 3/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0326 - mse: 0.0326
# Epoch 4/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0257 - mse: 0.0257
# Epoch 5/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0200 - mse: 0.0200
# Epoch 6/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0166 - mse: 0.0166
# Epoch 7/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0148 - mse: 0.0148
# Epoch 8/100
# 813/813 [==============================] - 4s 5ms/step - loss: 0.0137 - mse: 0.0137
# Epoch 9/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0126 - mse: 0.0126
# Epoch 10/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0119 - mse: 0.0119
# Epoch 11/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0109 - mse: 0.0109
# Epoch 12/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0105 - mse: 0.0105
# Epoch 13/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0099 - mse: 0.0099
# Epoch 14/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0095 - mse: 0.0095
# Epoch 15/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0095 - mse: 0.0095
# Epoch 16/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0090 - mse: 0.0090
# Epoch 17/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0085 - mse: 0.0085
# Epoch 18/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0080 - mse: 0.0080
# Epoch 19/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0079 - mse: 0.0079
# Epoch 20/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0079 - mse: 0.0079
# Epoch 21/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0076 - mse: 0.0076
# Epoch 22/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0075 - mse: 0.0075
# Epoch 23/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0077 - mse: 0.0077
# Epoch 24/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0072 - mse: 0.0072
# Epoch 25/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0080 - mse: 0.0080
# Epoch 26/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0070 - mse: 0.0070
# Epoch 27/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0070 - mse: 0.0070
# Epoch 28/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0070 - mse: 0.0070
# Epoch 29/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0069 - mse: 0.0069
# Epoch 30/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0072 - mse: 0.0072
# Epoch 31/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0065 - mse: 0.0065
# Epoch 32/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0071 - mse: 0.0071
# Epoch 33/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0065 - mse: 0.0065
# Epoch 34/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0067 - mse: 0.0067
# Epoch 35/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0068 - mse: 0.0068
# Epoch 36/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0065 - mse: 0.0065
# Epoch 37/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0065 - mse: 0.0065
# Epoch 38/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0066 - mse: 0.0066
# Epoch 39/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0063 - mse: 0.0063
# Epoch 40/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0066 - mse: 0.0066
# Epoch 41/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0059 - mse: 0.0059
# Epoch 42/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0064 - mse: 0.0064
# Epoch 43/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0060 - mse: 0.0060
# Epoch 44/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0062 - mse: 0.0062
# Epoch 45/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0062 - mse: 0.0062
# Epoch 46/100
# 813/813 [==============================] - 4s 4ms/step - loss: 0.0059 - mse: 0.0059
# Epoch 47/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0057 - mse: 0.0057
# Epoch 48/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0056 - mse: 0.0056
# Epoch 49/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0064 - mse: 0.0064
# Epoch 50/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0056 - mse: 0.0056
# Epoch 51/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0056 - mse: 0.0056
# Epoch 52/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0061 - mse: 0.0061
# Epoch 53/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0056 - mse: 0.0056
# Epoch 54/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0055 - mse: 0.0055
# Epoch 55/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0056 - mse: 0.0056
# Epoch 56/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0054 - mse: 0.0054
# Epoch 57/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0057 - mse: 0.0057A: 1s - lo
# Epoch 58/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0059 - mse: 0.0059
# Epoch 59/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0056 - mse: 0.0056
# Epoch 60/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0055 - mse: 0.0055
# Epoch 61/100
# 813/813 [==============================] - 4s 4ms/step - loss: 0.0054 - mse: 0.0054
# Epoch 62/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0050 - mse: 0.0050
# Epoch 63/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0055 - mse: 0.0055
# Epoch 64/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0058 - mse: 0.0058
# Epoch 65/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0053 - mse: 0.0053
# Epoch 66/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0053 - mse: 0.0053
# Epoch 67/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0051 - mse: 0.0051
# Epoch 68/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0052 - mse: 0.0052
# Epoch 69/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0049 - mse: 0.0049
# Epoch 70/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0052 - mse: 0.0052
# Epoch 71/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0051 - mse: 0.0051
# Epoch 72/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0049 - mse: 0.0049
# Epoch 73/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0048 - mse: 0.0048
# Epoch 74/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0054 - mse: 0.0054
# Epoch 75/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0047 - mse: 0.0047
# Epoch 76/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0047 - mse: 0.0047
# Epoch 77/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0047 - mse: 0.0047
# Epoch 78/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0047 - mse: 0.0047
# Epoch 79/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0048 - mse: 0.0048
# Epoch 80/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0048 - mse: 0.0048
# Epoch 81/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0048 - mse: 0.0048
# Epoch 82/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0046 - mse: 0.0046
# Epoch 83/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0047 - mse: 0.0047
# Epoch 84/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0045 - mse: 0.0045
# Epoch 85/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0047 - mse: 0.0047
# Epoch 86/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0045 - mse: 0.0045
# Epoch 87/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0045 - mse: 0.0045
# Epoch 88/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0046 - mse: 0.0046
# Epoch 89/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0044 - mse: 0.0044
# Epoch 90/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0044 - mse: 0.0044
# Epoch 91/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0044 - mse: 0.0044
# Epoch 92/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0043 - mse: 0.0043
# Epoch 93/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0045 - mse: 0.0045
# Epoch 94/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0043 - mse: 0.0043
# Epoch 95/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0042 - mse: 0.0042
# Epoch 96/100
# 813/813 [==============================] - 3s 3ms/step - loss: 0.0045 - mse: 0.0045
# Epoch 97/100
# 813/813 [==============================] - 3s 4ms/step - loss: 0.0043 - mse: 0.0043
# Epoch 98/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0041 - mse: 0.0041
# Epoch 99/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0044 - mse: 0.0044
# Epoch 100/100
# 813/813 [==============================] - 2s 3ms/step - loss: 0.0041 - mse: 0.0041
# Training r2_score = 0.9929204498178265
# Testing  r2_score = 0.9902985531091705

# %%
day_30 = get_days(df)[0]
d_temp = day_30[["date_updated","iso_code","total_cases_30","total_deaths_30"]]
du_30 = pd.DataFrame({"date_updated":day_30["date_updated"],"date_updated_30":day_30["date_updated_30"].iloc[:,1]})
day_30 = d_temp.merge(du_30,on=["date_updated"])
day_30
# Out:
#         date_updated iso_code  total_cases_30  total_deaths_30 date_updated_30
# 0         2020-03-13      ABW            92.0              0.0      2020-04-12
# 1         2020-03-13      ABW            92.0              0.0      2020-04-12
# 2         2020-03-13      ABW            92.0              0.0      2020-04-12
# 3         2020-03-13      ABW            92.0              0.0      2020-04-12
# 4         2020-03-13      ABW            92.0              0.0      2020-04-12
# ...              ...      ...             ...              ...             ...
# 4738918   2020-03-18      ZAF          2605.0             48.0      2020-04-17
# 4738919   2020-03-18      ZAF          2605.0             48.0      2020-04-17
# 4738920   2020-03-18      ZAF          2605.0             48.0      2020-04-17
# 4738921   2020-03-18      ZAF          2605.0             48.0      2020-04-17
# 4738922   2020-03-18      ZAF          2605.0             48.0      2020-04-17
#
# [4738923 rows x 5 columns]

# %%
# Dataframe to hold Iso_code, CountryName, Actual Deaths, Predicted Deaths, Actual Cases, Predicted Cases

acc_cases = pd.DataFrame()
acc_deaths = pd.DataFrame()

# %%
# Iterate through the country dataframes and retrieve the row for which date_updated_30 is 2020-08-31. The row 
# also contains total_(cases or deaths)_30, which is the actual number of cases (or deaths), and 
# total_(cases or deaths)_30_pred, the predicted number of cases (or deaths). 

for i,md in enumerate(models):
    
    # get the cleaned dataframe
    df = cleaned_df
    
    # get the model from md, the ml instance
    model = md.get_model()
    
    # get the feature set from the model
    features = md.get_feature_set().copy()
    
    # Get the StandardScaler instances for the features, X_scaler, and the target, y_scaler, from the model
    X_scaler = md.get_X_scaler()
    y_scaler = md.get_y_scaler()
    
    # Get the target name by concatenating the target (cases or deaths) with the model period (30 days)
    target = md.get_target() + "_" + md.get_period()
    
    # For each country code
    for code in iso_codes:
        
        # Get the feature dataframe
        X = df[df["iso_code"] == code][md.get_feature_set()]
        
        # Scale the feature dataframe
        X_scaled = X_scaler.transform(X)
        
        # Get the predicted target values (scaled)
        y_pred_scaled = model.predict(X_scaled)
        
        # Get the predicted target values (unscaled)
        y_pred = y_scaler.inverse_transform(y_pred_scaled)
        
        # Get the dataframe for the current country code
        df_ic = df[df["iso_code"] == code].copy()
        
        # Create the time list by converting the date_updated column to string
        time = [str(t) for t in df_ic["date_updated"]]
        
        # Get the date values list
        x_vals = df_ic["date_updated"].values.tolist()
        
        # Get the target values list (ignore the errors)
        try:
            y_test = df_ic[target].values.tolist()
        except:
            # Just keep going
            pass

        # Create the feature string to be used in the filename when saving the data to disk    
        feature_str = ""
        for feature in features:
            if re.search('^[CEH\d]',feature) == None:
                feature_str = feature_str + "_" + feature
            else:
                feature_str = feature_str + "_" + feature[:2]
        
        # Add the predicted-values column to the dataframe
        df_ic[target + "_pred"] = y_pred
        
        # Merge the dataframe with day_30, the dataframe which contains the future case and death values
        df_ic = df_ic.merge(day_30,on=["date_updated","iso_code"],how="left")
        
        # Grab the row in which date_updated_30 is 2020-08-31
        print(" ============================================ >>>>>>>>>>>>>>>>>>>>>>")
        to_append = df_ic[df_ic["date_updated_30"] == "2020-08-31"][["iso_code","location","date_updated_30",target,target+"_pred"]]
        to_append = to_append.iloc[0]
        
        # Show the values to append and the target column being generated
        print(to_append)
        print(f"target = {target}")
        
        # Depending on the target being generated, add the new row to acc_deaths or acc_cases
        if "deaths" in target:
            acc_deaths = acc_deaths.append(to_append)
        else:
            acc_cases = acc_cases.append(to_append)
         
        # Output the predictions to a csv file in the predictions folder
        df_ic.to_csv(f"Resources/predictions/target-{target}-country-{code}.csv")
        
        # Plot the graphs comparing predicted values to actual values
        plt.figure(figsize=[25,15])
        plt.plot(df_ic["date_updated"], df_ic[target], c="Red")
        plt.plot(df_ic["date_updated"], df_ic[target + "_pred"], c="Blue")
        
        plt.xlabel("Time")
        plt.ylabel("Actual/Predicted")
        
        plt.title(md.get_title() + "; Country: " + code)
        plt.xticks(rotation=90)
        plt.legend(["Actual","Predicted"])        
        
        plt.savefig(f"Resources/graphs/target-{md.get_target()}-country-{code}.png")
        plt.close()
# Out:
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      ABW
# location                    Aruba
# date_updated_30        2020-08-31
# total_cases_30               1997
# total_cases_30_pred       6577.97
# Name: 21869, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       AFG
# location               Afghanistan
# date_updated_30         2020-08-31
# total_cases_30               38162
# total_cases_30_pred        37563.9
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      AGO
# location                   Angola
# date_updated_30        2020-08-31
# total_cases_30               2624
# total_cases_30_pred       5659.27
# Name: 21346, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      ALB
# location                  Albania
# date_updated_30        2020-08-31
# total_cases_30               9380
# total_cases_30_pred       3928.81
# Name: 22837, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                                ARE
# location               United Arab Emirates
# date_updated_30                  2020-08-31
# total_cases_30                        69690
# total_cases_30_pred                 63414.3
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      ARG
# location                Argentina
# date_updated_30        2020-08-31
# total_cases_30             401226
# total_cases_30_pred        359516
# Name: 24692, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      AUS
# location                Australia
# date_updated_30        2020-08-31
# total_cases_30              25670
# total_cases_30_pred       31254.8
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      AUT
# location                  Austria
# date_updated_30        2020-08-31
# total_cases_30              27218
# total_cases_30_pred       32442.9
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      AZE
# location               Azerbaijan
# date_updated_30        2020-08-31
# total_cases_30              36309
# total_cases_30_pred         36067
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      BDI
# location                  Burundi
# date_updated_30        2020-08-31
# total_cases_30                445
# total_cases_30_pred        3160.1
# Name: 19805, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      BEL
# location                  Belgium
# date_updated_30        2020-08-31
# total_cases_30              84948
# total_cases_30_pred       53512.5
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      BEN
# location                    Benin
# date_updated_30        2020-08-31
# total_cases_30               2145
# total_cases_30_pred       5914.27
# Name: 22022, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                        BFA
# location               Burkina Faso
# date_updated_30          2020-08-31
# total_cases_30                 1368
# total_cases_30_pred        -6833.29
# Name: 22452, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      BGD
# location               Bangladesh
# date_updated_30        2020-08-31
# total_cases_30             310822
# total_cases_30_pred        324438
# Name: 23237, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      BGR
# location                 Bulgaria
# date_updated_30        2020-08-31
# total_cases_30              16190
# total_cases_30_pred       17149.5
# Name: 22741, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      BHR
# location                  Bahrain
# date_updated_30        2020-08-31
# total_cases_30              51574
# total_cases_30_pred       62451.1
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                                  BIH
# location               Bosnia and Herzegovina
# date_updated_30                    2020-08-31
# total_cases_30                          19789
# total_cases_30_pred                   17117.1
# Name: 22650, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      BLR
# location                  Belarus
# date_updated_30        2020-08-31
# total_cases_30              71687
# total_cases_30_pred       79867.7
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      BLZ
# location                   Belize
# date_updated_30        2020-08-31
# total_cases_30                994
# total_cases_30_pred       83.3523
# Name: 21046, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      BOL
# location                  Bolivia
# date_updated_30        2020-08-31
# total_cases_30             115968
# total_cases_30_pred        132095
# Name: 22569, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       BRA
# location                    Brazil
# date_updated_30         2020-08-31
# total_cases_30         3.86231e+06
# total_cases_30_pred    3.93768e+06
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      BRB
# location                 Barbados
# date_updated_30        2020-08-31
# total_cases_30                173
# total_cases_30_pred      -1474.26
# Name: 21895, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      BRN
# location                   Brunei
# date_updated_30        2020-08-31
# total_cases_30                144
# total_cases_30_pred      -6009.93
# Name: 22658, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      BTN
# location                   Bhutan
# date_updated_30        2020-08-31
# total_cases_30                224
# total_cases_30_pred       504.442
# Name: 22650, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      BWA
# location                 Botswana
# date_updated_30        2020-08-31
# total_cases_30               1633
# total_cases_30_pred       6294.48
# Name: 19805, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                                    CAF
# location               Central African Republic
# date_updated_30                      2020-08-31
# total_cases_30                             4700
# total_cases_30_pred                     7039.31
# Name: 22143, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      CAN
# location                   Canada
# date_updated_30        2020-08-31
# total_cases_30             127940
# total_cases_30_pred        145168
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       CHE
# location               Switzerland
# date_updated_30         2020-08-31
# total_cases_30               41906
# total_cases_30_pred        48794.6
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      CHL
# location                    Chile
# date_updated_30        2020-08-31
# total_cases_30             409974
# total_cases_30_pred        495396
# Name: 23153, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      CHN
# location                    China
# date_updated_30        2020-08-31
# total_cases_30              89895
# total_cases_30_pred       98779.2
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                         CIV
# location               Cote d'Ivoire
# date_updated_30           2020-08-31
# total_cases_30                 17948
# total_cases_30_pred          22481.9
# Name: 22361, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      CMR
# location                 Cameroon
# date_updated_30        2020-08-31
# total_cases_30              19142
# total_cases_30_pred         20137
# Name: 22639, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                                        COD
# location               Democratic Republic of Congo
# date_updated_30                          2020-08-31
# total_cases_30                                10044
# total_cases_30_pred                         19439.1
# Name: 22456, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      COG
# location                    Congo
# date_updated_30        2020-08-31
# total_cases_30               3979
# total_cases_30_pred          7537
# Name: 22143, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      COL
# location                 Colombia
# date_updated_30        2020-08-31
# total_cases_30             607938
# total_cases_30_pred        598370
# Name: 23161, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      CPV
# location               Cape Verde
# date_updated_30        2020-08-31
# total_cases_30               3852
# total_cases_30_pred        3884.9
# Name: 21491, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      CRI
# location               Costa Rica
# date_updated_30        2020-08-31
# total_cases_30              39699
# total_cases_30_pred       27366.1
# Name: 22920, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      CUB
# location                     Cuba
# date_updated_30        2020-08-31
# total_cases_30               3973
# total_cases_30_pred       3869.07
# Name: 22218, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      CYP
# location                   Cyprus
# date_updated_30        2020-08-31
# total_cases_30               1487
# total_cases_30_pred       1701.97
# Name: 22555, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                          CZE
# location               Czech Republic
# date_updated_30            2020-08-31
# total_cases_30                  24367
# total_cases_30_pred             26502
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      DEU
# location                  Germany
# date_updated_30        2020-08-31
# total_cases_30             242381
# total_cases_30_pred        191730
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      DJI
# location                 Djibouti
# date_updated_30        2020-08-31
# total_cases_30               5385
# total_cases_30_pred       8603.25
# Name: 21766, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      DNK
# location                  Denmark
# date_updated_30        2020-08-31
# total_cases_30              16700
# total_cases_30_pred         20155
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                              DOM
# location               Dominican Republic
# date_updated_30                2020-08-31
# total_cases_30                      94241
# total_cases_30_pred               78036.6
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      DZA
# location                  Algeria
# date_updated_30        2020-08-31
# total_cases_30              44146
# total_cases_30_pred       80957.5
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      ECU
# location                  Ecuador
# date_updated_30        2020-08-31
# total_cases_30             113648
# total_cases_30_pred       80615.5
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      EGY
# location                    Egypt
# date_updated_30        2020-08-31
# total_cases_30              98727
# total_cases_30_pred        100420
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      ERI
# location                  Eritrea
# date_updated_30        2020-08-31
# total_cases_30                318
# total_cases_30_pred      -743.714
# Name: 21346, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      ESP
# location                    Spain
# date_updated_30        2020-08-31
# total_cases_30                NaN
# total_cases_30_pred        435508
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      EST
# location                  Estonia
# date_updated_30        2020-08-31
# total_cases_30               2373
# total_cases_30_pred       2233.75
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      ETH
# location                 Ethiopia
# date_updated_30        2020-08-31
# total_cases_30              51122
# total_cases_30_pred       34170.8
# Name: 22365, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      FIN
# location                  Finland
# date_updated_30        2020-08-31
# total_cases_30               8077
# total_cases_30_pred       11005.5
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      FJI
# location                     Fiji
# date_updated_30        2020-08-31
# total_cases_30                 28
# total_cases_30_pred      -2506.86
# Name: 25445, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      FRA
# location                   France
# date_updated_30        2020-08-31
# total_cases_30             277943
# total_cases_30_pred        231548
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      GAB
# location                    Gabon
# date_updated_30        2020-08-31
# total_cases_30               8505
# total_cases_30_pred       11676.8
# Name: 22363, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                          GBR
# location               United Kingdom
# date_updated_30            2020-08-31
# total_cases_30                 334467
# total_cases_30_pred            336684
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      GEO
# location                  Georgia
# date_updated_30        2020-08-31
# total_cases_30               1487
# total_cases_30_pred       5047.37
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      GHA
# location                    Ghana
# date_updated_30        2020-08-31
# total_cases_30              44205
# total_cases_30_pred       52830.8
# Name: 22363, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      GIN
# location                   Guinea
# date_updated_30        2020-08-31
# total_cases_30               9371
# total_cases_30_pred       14505.3
# Name: 22244, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      GMB
# location                   Gambia
# date_updated_30        2020-08-31
# total_cases_30               2963
# total_cases_30_pred      -9476.56
# Name: 21895, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      GRC
# location                   Greece
# date_updated_30        2020-08-31
# total_cases_30              10134
# total_cases_30_pred       -2658.9
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      GTM
# location                Guatemala
# date_updated_30        2020-08-31
# total_cases_30              73912
# total_cases_30_pred       76451.2
# Name: 22260, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      GUM
# location                     Guam
# date_updated_30        2020-08-31
# total_cases_30               1347
# total_cases_30_pred       2401.78
# Name: 21766, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      GUY
# location                   Guyana
# date_updated_30        2020-08-31
# total_cases_30               1234
# total_cases_30_pred      -516.167
# Name: 22246, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      HKG
# location                Hong Kong
# date_updated_30        2020-08-31
# total_cases_30                NaN
# total_cases_30_pred      -5063.99
# Name: 943, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      HND
# location                 Honduras
# date_updated_30        2020-08-31
# total_cases_30              60174
# total_cases_30_pred       78721.5
# Name: 22349, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      HRV
# location                  Croatia
# date_updated_30        2020-08-31
# total_cases_30              10123
# total_cases_30_pred       13032.1
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      HTI
# location                    Haiti
# date_updated_30        2020-08-31
# total_cases_30               8209
# total_cases_30_pred       7151.55
# Name: 21630, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      HUN
# location                  Hungary
# date_updated_30        2020-08-31
# total_cases_30               5961
# total_cases_30_pred          7232
# Name: 23237, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      IDN
# location                Indonesia
# date_updated_30        2020-08-31
# total_cases_30             172053
# total_cases_30_pred        158284
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       IND
# location                     India
# date_updated_30         2020-08-31
# total_cases_30         3.62124e+06
# total_cases_30_pred     3.6845e+06
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      IRL
# location                  Ireland
# date_updated_30        2020-08-31
# total_cases_30              28760
# total_cases_30_pred       37231.7
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      IRN
# location                     Iran
# date_updated_30        2020-08-31
# total_cases_30             373570
# total_cases_30_pred        415200
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      IRQ
# location                     Iraq
# date_updated_30        2020-08-31
# total_cases_30             231177
# total_cases_30_pred        223720
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      ISL
# location                  Iceland
# date_updated_30        2020-08-31
# total_cases_30               2105
# total_cases_30_pred      -3672.23
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      ISR
# location                   Israel
# date_updated_30        2020-08-31
# total_cases_30             114020
# total_cases_30_pred        105956
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      ITA
# location                    Italy
# date_updated_30        2020-08-31
# total_cases_30             268218
# total_cases_30_pred        264395
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      JAM
# location                  Jamaica
# date_updated_30        2020-08-31
# total_cases_30               2357
# total_cases_30_pred      -2845.46
# Name: 22452, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      JOR
# location                   Jordan
# date_updated_30        2020-08-31
# total_cases_30               1966
# total_cases_30_pred      -3428.43
# Name: 22994, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      JPN
# location                    Japan
# date_updated_30        2020-08-31
# total_cases_30              67865
# total_cases_30_pred       49454.1
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      KAZ
# location               Kazakhstan
# date_updated_30        2020-08-31
# total_cases_30             130673
# total_cases_30_pred        187720
# Name: 22468, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      KEN
# location                    Kenya
# date_updated_30        2020-08-31
# total_cases_30              34057
# total_cases_30_pred         28682
# Name: 23085, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      KGZ
# location               Kyrgyzstan
# date_updated_30        2020-08-31
# total_cases_30              43898
# total_cases_30_pred       76341.7
# Name: 21766, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      KHM
# location                 Cambodia
# date_updated_30        2020-08-31
# total_cases_30                274
# total_cases_30_pred       209.645
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       KOR
# location               South Korea
# date_updated_30         2020-08-31
# total_cases_30               19947
# total_cases_30_pred        19576.4
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      KWT
# location                   Kuwait
# date_updated_30        2020-08-31
# total_cases_30              84636
# total_cases_30_pred       75602.3
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      LAO
# location                     Laos
# date_updated_30        2020-08-31
# total_cases_30                 22
# total_cases_30_pred      -2318.26
# Name: 20894, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      LBN
# location                  Lebanon
# date_updated_30        2020-08-31
# total_cases_30              16870
# total_cases_30_pred       11533.3
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      LBR
# location                  Liberia
# date_updated_30        2020-08-31
# total_cases_30               1304
# total_cases_30_pred       6239.57
# Name: 22022, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      LBY
# location                    Libya
# date_updated_30        2020-08-31
# total_cases_30              13423
# total_cases_30_pred       10796.1
# Name: 20894, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      LKA
# location                Sri Lanka
# date_updated_30        2020-08-31
# total_cases_30               3012
# total_cases_30_pred       15896.9
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      LSO
# location                  Lesotho
# date_updated_30        2020-08-31
# total_cases_30               1066
# total_cases_30_pred          3703
# Name: 12717, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      LTU
# location                Lithuania
# date_updated_30        2020-08-31
# total_cases_30               2874
# total_cases_30_pred      -1998.55
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      LUX
# location               Luxembourg
# date_updated_30        2020-08-31
# total_cases_30               6625
# total_cases_30_pred       8929.69
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      LVA
# location                   Latvia
# date_updated_30        2020-08-31
# total_cases_30               1393
# total_cases_30_pred       4009.28
# Name: 23518, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      MAR
# location                  Morocco
# date_updated_30        2020-08-31
# total_cases_30              61399
# total_cases_30_pred       56399.7
# Name: 24948, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      MDA
# location                  Moldova
# date_updated_30        2020-08-31
# total_cases_30              36700
# total_cases_30_pred       26282.8
# Name: 22744, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      MDG
# location               Madagascar
# date_updated_30        2020-08-31
# total_cases_30              14843
# total_cases_30_pred       28927.1
# Name: 21491, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      MEX
# location                   Mexico
# date_updated_30        2020-08-31
# total_cases_30             595841
# total_cases_30_pred        581394
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      MLI
# location                     Mali
# date_updated_30        2020-08-31
# total_cases_30               2773
# total_cases_30_pred        1699.1
# Name: 20740, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      MMR
# location                  Myanmar
# date_updated_30        2020-08-31
# total_cases_30                787
# total_cases_30_pred         11891
# Name: 21324, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      MNG
# location                 Mongolia
# date_updated_30        2020-08-31
# total_cases_30                301
# total_cases_30_pred      -3651.32
# Name: 22349, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      MOZ
# location               Mozambique
# date_updated_30        2020-08-31
# total_cases_30               3821
# total_cases_30_pred       1907.03
# Name: 21197, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      MRT
# location               Mauritania
# date_updated_30        2020-08-31
# total_cases_30               7022
# total_cases_30_pred       5438.02
# Name: 22260, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      MUS
# location                Mauritius
# date_updated_30        2020-08-31
# total_cases_30                346
# total_cases_30_pred      -3220.39
# Name: 21630, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      MWI
# location                   Malawi
# date_updated_30        2020-08-31
# total_cases_30               5536
# total_cases_30_pred       6512.16
# Name: 19487, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      MYS
# location                 Malaysia
# date_updated_30        2020-08-31
# total_cases_30               9334
# total_cases_30_pred       9274.52
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      NAM
# location                  Namibia
# date_updated_30        2020-08-31
# total_cases_30               7365
# total_cases_30_pred       5133.05
# Name: 22260, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      NER
# location                    Niger
# date_updated_30        2020-08-31
# total_cases_30               1176
# total_cases_30_pred      -2026.04
# Name: 21491, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      NGA
# location                  Nigeria
# date_updated_30        2020-08-31
# total_cases_30              53865
# total_cases_30_pred       44898.3
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      NIC
# location                Nicaragua
# date_updated_30        2020-08-31
# total_cases_30               4494
# total_cases_30_pred       3705.96
# Name: 21766, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       NLD
# location               Netherlands
# date_updated_30         2020-08-31
# total_cases_30               70071
# total_cases_30_pred        57618.4
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      NOR
# location                   Norway
# date_updated_30        2020-08-31
# total_cases_30              10543
# total_cases_30_pred       16121.5
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      NPL
# location                    Nepal
# date_updated_30        2020-08-31
# total_cases_30              38561
# total_cases_30_pred       17634.7
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       NZL
# location               New Zealand
# date_updated_30         2020-08-31
# total_cases_30                1387
# total_cases_30_pred         489.88
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      OMN
# location                     Oman
# date_updated_30        2020-08-31
# total_cases_30              85544
# total_cases_30_pred       86129.9
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      PAK
# location                 Pakistan
# date_updated_30        2020-08-31
# total_cases_30             295849
# total_cases_30_pred        331917
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      PAN
# location                   Panama
# date_updated_30        2020-08-31
# total_cases_30              92065
# total_cases_30_pred       77783.6
# Name: 22837, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      PER
# location                     Peru
# date_updated_30        2020-08-31
# total_cases_30             647166
# total_cases_30_pred        672267
# Name: 23585, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       PHL
# location               Philippines
# date_updated_30         2020-08-31
# total_cases_30              217396
# total_cases_30_pred         210201
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                            PNG
# location               Papua New Guinea
# date_updated_30              2020-08-31
# total_cases_30                      459
# total_cases_30_pred               -1273
# Name: 21491, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      POL
# location                   Poland
# date_updated_30        2020-08-31
# total_cases_30              66870
# total_cases_30_pred       60153.8
# Name: 23080, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       PRI
# location               Puerto Rico
# date_updated_30         2020-08-31
# total_cases_30               32848
# total_cases_30_pred        20150.5
# Name: 20430, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      PRT
# location                 Portugal
# date_updated_30        2020-08-31
# total_cases_30              57768
# total_cases_30_pred       42857.8
# Name: 23449, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      PRY
# location                 Paraguay
# date_updated_30        2020-08-31
# total_cases_30              17195
# total_cases_30_pred       15402.5
# Name: 23004, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      PSE
# location                Palestine
# date_updated_30        2020-08-31
# total_cases_30              29063
# total_cases_30_pred       28855.4
# Name: 22997, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      QAT
# location                    Qatar
# date_updated_30        2020-08-31
# total_cases_30             118575
# total_cases_30_pred        136072
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      ROU
# location                  Romania
# date_updated_30        2020-08-31
# total_cases_30              86785
# total_cases_30_pred       76545.3
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       RUS
# location                    Russia
# date_updated_30         2020-08-31
# total_cases_30              990326
# total_cases_30_pred    1.01263e+06
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      RWA
# location                   Rwanda
# date_updated_30        2020-08-31
# total_cases_30               4020
# total_cases_30_pred       8484.72
# Name: 22260, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                        SAU
# location               Saudi Arabia
# date_updated_30          2020-08-31
# total_cases_30               314821
# total_cases_30_pred          340783
# Name: 23075, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      SDN
# location                    Sudan
# date_updated_30        2020-08-31
# total_cases_30              13189
# total_cases_30_pred       26948.3
# Name: 22365, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      SEN
# location                  Senegal
# date_updated_30        2020-08-31
# total_cases_30              13556
# total_cases_30_pred       9702.63
# Name: 23380, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      SGP
# location                Singapore
# date_updated_30        2020-08-31
# total_cases_30              56771
# total_cases_30_pred       52549.3
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                        SLE
# location               Sierra Leone
# date_updated_30          2020-08-31
# total_cases_30                 2022
# total_cases_30_pred         430.149
# Name: 19805, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       SLV
# location               El Salvador
# date_updated_30         2020-08-31
# total_cases_30               25729
# total_cases_30_pred        42787.1
# Name: 21766, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      SOM
# location                  Somalia
# date_updated_30        2020-08-31
# total_cases_30               3310
# total_cases_30_pred       4490.75
# Name: 22022, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      SRB
# location                   Serbia
# date_updated_30        2020-08-31
# total_cases_30              31365
# total_cases_30_pred       39727.6
# Name: 23717, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      SUR
# location                 Suriname
# date_updated_30        2020-08-31
# total_cases_30               4009
# total_cases_30_pred        4250.5
# Name: 21608, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      SVK
# location                 Slovakia
# date_updated_30        2020-08-31
# total_cases_30               3876
# total_cases_30_pred       4181.23
# Name: 22915, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      SVN
# location                 Slovenia
# date_updated_30        2020-08-31
# total_cases_30               2865
# total_cases_30_pred      -2382.09
# Name: 23072, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      SWE
# location                   Sweden
# date_updated_30        2020-08-31
# total_cases_30              83958
# total_cases_30_pred       77976.4
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      SWZ
# location                Swaziland
# date_updated_30        2020-08-31
# total_cases_30               4561
# total_cases_30_pred       5711.25
# Name: 22260, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      SYC
# location               Seychelles
# date_updated_30        2020-08-31
# total_cases_30                136
# total_cases_30_pred      -2451.23
# Name: 22260, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      TCD
# location                     Chad
# date_updated_30        2020-08-31
# total_cases_30               1012
# total_cases_30_pred       6005.44
# Name: 21630, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      TGO
# location                     Togo
# date_updated_30        2020-08-31
# total_cases_30               1396
# total_cases_30_pred       3834.82
# Name: 23237, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      THA
# location                 Thailand
# date_updated_30        2020-08-31
# total_cases_30               3412
# total_cases_30_pred       13279.6
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      TJK
# location               Tajikistan
# date_updated_30        2020-08-31
# total_cases_30               8550
# total_cases_30_pred       11517.8
# Name: 14985, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      TLS
# location                    Timor
# date_updated_30        2020-08-31
# total_cases_30                 27
# total_cases_30_pred       1547.61
# Name: 21346, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                               TTO
# location               Trinidad and Tobago
# date_updated_30                 2020-08-31
# total_cases_30                        1683
# total_cases_30_pred               -3623.78
# Name: 22468, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      TUN
# location                  Tunisia
# date_updated_30        2020-08-31
# total_cases_30               3685
# total_cases_30_pred       3300.57
# Name: 22910, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      TUR
# location                   Turkey
# date_updated_30        2020-08-31
# total_cases_30             268546
# total_cases_30_pred        280544
# Name: 22347, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      TZA
# location                 Tanzania
# date_updated_30        2020-08-31
# total_cases_30                509
# total_cases_30_pred       8225.93
# Name: 22022, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      UGA
# location                   Uganda
# date_updated_30        2020-08-31
# total_cases_30               2928
# total_cases_30_pred       5719.84
# Name: 21346, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      UKR
# location                  Ukraine
# date_updated_30        2020-08-31
# total_cases_30             119074
# total_cases_30_pred       80714.8
# Name: 22825, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      URY
# location                  Uruguay
# date_updated_30        2020-08-31
# total_cases_30               1585
# total_cases_30_pred       6264.93
# Name: 22260, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                         USA
# location               United States
# date_updated_30           2020-08-31
# total_cases_30           5.99716e+06
# total_cases_30_pred      6.14212e+06
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      UZB
# location               Uzbekistan
# date_updated_30        2020-08-31
# total_cases_30              41651
# total_cases_30_pred       38070.4
# Name: 22143, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      VEN
# location                Venezuela
# date_updated_30        2020-08-31
# total_cases_30              45868
# total_cases_30_pred       47818.7
# Name: 22260, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      VNM
# location                  Vietnam
# date_updated_30        2020-08-31
# total_cases_30               1040
# total_cases_30_pred       19109.2
# Name: 27214, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      YEM
# location                    Yemen
# date_updated_30        2020-08-31
# total_cases_30               1953
# total_cases_30_pred       3936.51
# Name: 18367, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                        ZAF
# location               South Africa
# date_updated_30          2020-08-31
# total_cases_30               625056
# total_cases_30_pred          679882
# Name: 24948, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      ZMB
# location                   Zambia
# date_updated_30        2020-08-31
# total_cases_30              12025
# total_cases_30_pred       7402.12
# Name: 21766, dtype: object
# target = total_cases_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                      ZWE
# location                 Zimbabwe
# date_updated_30        2020-08-31
# ...
# date_updated_30         2020-08-31
# total_deaths_30                137
# total_deaths_30_pred      -89.8194
# Name: 21766, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                        NLD
# location                Netherlands
# date_updated_30          2020-08-31
# total_deaths_30                6215
# total_deaths_30_pred        6115.17
# Name: 27214, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       NOR
# location                    Norway
# date_updated_30         2020-08-31
# total_deaths_30                264
# total_deaths_30_pred       260.335
# Name: 27214, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       NPL
# location                     Nepal
# date_updated_30         2020-08-31
# total_deaths_30                221
# total_deaths_30_pred        17.372
# Name: 27214, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                        NZL
# location                New Zealand
# date_updated_30          2020-08-31
# total_deaths_30                  22
# total_deaths_30_pred         173.31
# Name: 27214, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       OMN
# location                      Oman
# date_updated_30         2020-08-31
# total_deaths_30                677
# total_deaths_30_pred       1280.62
# Name: 27214, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       PAK
# location                  Pakistan
# date_updated_30         2020-08-31
# total_deaths_30               6294
# total_deaths_30_pred       5873.45
# Name: 27214, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       PAN
# location                    Panama
# date_updated_30         2020-08-31
# total_deaths_30               1995
# total_deaths_30_pred       2127.62
# Name: 22837, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       PER
# location                      Peru
# date_updated_30         2020-08-31
# total_deaths_30              28788
# total_deaths_30_pred       25939.5
# Name: 23585, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                        PHL
# location                Philippines
# date_updated_30          2020-08-31
# total_deaths_30                3520
# total_deaths_30_pred         3524.5
# Name: 27214, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                             PNG
# location                Papua New Guinea
# date_updated_30               2020-08-31
# total_deaths_30                        5
# total_deaths_30_pred            -185.645
# Name: 21491, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       POL
# location                    Poland
# date_updated_30         2020-08-31
# total_deaths_30               2033
# total_deaths_30_pred       2970.19
# Name: 23080, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                        PRI
# location                Puerto Rico
# date_updated_30          2020-08-31
# total_deaths_30                 434
# total_deaths_30_pred        1008.09
# Name: 20430, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       PRT
# location                  Portugal
# date_updated_30         2020-08-31
# total_deaths_30               1819
# total_deaths_30_pred       3187.81
# Name: 23449, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       PRY
# location                  Paraguay
# date_updated_30         2020-08-31
# total_deaths_30                308
# total_deaths_30_pred       749.471
# Name: 23004, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       PSE
# location                 Palestine
# date_updated_30         2020-08-31
# total_deaths_30                166
# total_deaths_30_pred      -121.953
# Name: 22997, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       QAT
# location                     Qatar
# date_updated_30         2020-08-31
# total_deaths_30                197
# total_deaths_30_pred       1495.87
# Name: 27214, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       ROU
# location                   Romania
# date_updated_30         2020-08-31
# total_deaths_30               3578
# total_deaths_30_pred       3317.01
# Name: 27214, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       RUS
# location                    Russia
# date_updated_30         2020-08-31
# total_deaths_30              17093
# total_deaths_30_pred       13254.1
# Name: 27214, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       RWA
# location                    Rwanda
# date_updated_30         2020-08-31
# total_deaths_30                 16
# total_deaths_30_pred       76.5873
# Name: 22260, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                         SAU
# location                Saudi Arabia
# date_updated_30           2020-08-31
# total_deaths_30                 3870
# total_deaths_30_pred         5143.35
# Name: 23075, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       SDN
# location                     Sudan
# date_updated_30         2020-08-31
# total_deaths_30                823
# total_deaths_30_pred       904.418
# Name: 22365, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       SEN
# location                   Senegal
# date_updated_30         2020-08-31
# total_deaths_30                284
# total_deaths_30_pred       173.657
# Name: 23380, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       SGP
# location                 Singapore
# date_updated_30         2020-08-31
# total_deaths_30                 27
# total_deaths_30_pred       345.147
# Name: 27214, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                         SLE
# location                Sierra Leone
# date_updated_30           2020-08-31
# total_deaths_30                   70
# total_deaths_30_pred         288.002
# Name: 19805, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                        SLV
# location                El Salvador
# date_updated_30          2020-08-31
# total_deaths_30                 717
# total_deaths_30_pred        1003.99
# Name: 21766, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       SOM
# location                   Somalia
# date_updated_30         2020-08-31
# total_deaths_30                 98
# total_deaths_30_pred       5.53265
# Name: 22022, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       SRB
# location                    Serbia
# date_updated_30         2020-08-31
# total_deaths_30                711
# total_deaths_30_pred        628.51
# Name: 23717, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       SUR
# location                  Suriname
# date_updated_30         2020-08-31
# total_deaths_30                 67
# total_deaths_30_pred      -294.181
# Name: 21608, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       SVK
# location                  Slovakia
# date_updated_30         2020-08-31
# total_deaths_30                 33
# total_deaths_30_pred       305.514
# Name: 22915, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       SVN
# location                  Slovenia
# date_updated_30         2020-08-31
# total_deaths_30                128
# total_deaths_30_pred        90.809
# Name: 23072, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       SWE
# location                    Sweden
# date_updated_30         2020-08-31
# total_deaths_30               5821
# total_deaths_30_pred        6550.5
# Name: 27214, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       SWZ
# location                 Swaziland
# date_updated_30         2020-08-31
# total_deaths_30                 91
# total_deaths_30_pred       357.897
# Name: 22260, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       SYC
# location                Seychelles
# date_updated_30         2020-08-31
# total_deaths_30                  0
# total_deaths_30_pred       64.4687
# Name: 22260, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       TCD
# location                      Chad
# date_updated_30         2020-08-31
# total_deaths_30                 77
# total_deaths_30_pred       301.573
# Name: 21630, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       TGO
# location                      Togo
# date_updated_30         2020-08-31
# total_deaths_30                 27
# total_deaths_30_pred       1.83539
# Name: 23237, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       THA
# location                  Thailand
# date_updated_30         2020-08-31
# total_deaths_30                 58
# total_deaths_30_pred      -3.00128
# Name: 27214, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       TJK
# location                Tajikistan
# date_updated_30         2020-08-31
# total_deaths_30                 68
# total_deaths_30_pred       -292.94
# Name: 14985, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       TLS
# location                     Timor
# date_updated_30         2020-08-31
# total_deaths_30                  0
# total_deaths_30_pred       335.304
# Name: 21346, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                                TTO
# location                Trinidad and Tobago
# date_updated_30                  2020-08-31
# total_deaths_30                          21
# total_deaths_30_pred                322.851
# Name: 22468, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       TUN
# location                   Tunisia
# date_updated_30         2020-08-31
# total_deaths_30                 76
# total_deaths_30_pred         20.52
# Name: 22910, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       TUR
# location                    Turkey
# date_updated_30         2020-08-31
# total_deaths_30               6326
# total_deaths_30_pred       5889.79
# Name: 22347, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       TZA
# location                  Tanzania
# date_updated_30         2020-08-31
# total_deaths_30                 21
# total_deaths_30_pred       351.224
# Name: 22022, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       UGA
# location                    Uganda
# date_updated_30         2020-08-31
# total_deaths_30                 30
# total_deaths_30_pred       75.7868
# Name: 21346, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       UKR
# location                   Ukraine
# date_updated_30         2020-08-31
# total_deaths_30               2527
# total_deaths_30_pred       1422.78
# Name: 22825, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       URY
# location                   Uruguay
# date_updated_30         2020-08-31
# total_deaths_30                 44
# total_deaths_30_pred      -44.7899
# Name: 22260, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                          USA
# location                United States
# date_updated_30            2020-08-31
# total_deaths_30                183069
# total_deaths_30_pred           172587
# Name: 27214, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       UZB
# location                Uzbekistan
# date_updated_30         2020-08-31
# total_deaths_30                317
# total_deaths_30_pred       889.278
# Name: 22143, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       VEN
# location                 Venezuela
# date_updated_30         2020-08-31
# total_deaths_30                381
# total_deaths_30_pred       680.323
# Name: 22260, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       VNM
# location                   Vietnam
# date_updated_30         2020-08-31
# total_deaths_30                 32
# total_deaths_30_pred       224.508
# Name: 27214, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       YEM
# location                     Yemen
# date_updated_30         2020-08-31
# total_deaths_30                564
# total_deaths_30_pred       90.4426
# Name: 18367, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                         ZAF
# location                South Africa
# date_updated_30           2020-08-31
# total_deaths_30                14028
# total_deaths_30_pred         12869.4
# Name: 24948, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       ZMB
# location                    Zambia
# date_updated_30         2020-08-31
# total_deaths_30                287
# total_deaths_30_pred       346.565
# Name: 21766, dtype: object
# target = total_deaths_30
#  ============================================ >>>>>>>>>>>>>>>>>>>>>>
# iso_code                       ZWE
# location                  Zimbabwe
# date_updated_30         2020-08-31
# total_deaths_30                196
# total_deaths_30_pred       266.872
# Name: 21491, dtype: object
# target = total_deaths_30

# %%
# Save the acc_cases and acc_deaths dataframes to csv
acc_cases.to_csv("Cases_ActualvsPredicted.csv")
acc_deaths.to_csv("Deaths_ActualvsPredicted.csv")

# %%
acc_cases.shape
# Out:
# (165, 5)

# %%
acc_deaths.shape
# Out:
# (164, 5)
