# %%
# Import the dependencies

import numpy as np
import pandas as pd
import re

from matplotlib import pyplot as plt
from sklearn.metrics import r2_score

from datetime import timedelta,datetime

import sys
from path import Path

# import plotly.graph_objects as go

# %%
# Import the user-defined ml class

class_path = Path("../classes/pmmfs_ml")
sys.path.append(class_path)
from ml import ml

from ml_util import *

# %%
cleaned_df = pd.read_csv("Resources/cleaned_df.csv")

# %%
# Create four dataframes, one for each feature set to be explored for predicting future total cases and total deaths

df = cleaned_df[['date','iso_code','population','population_density','median_age','C1_School closing','C2_Workplace closing','C3_Cancel public events','C6_Stay at home requirements','C7_Restrictions on internal movement','C8_International travel controls','total_cases','total_deaths']]

# %%
# Earlier EDA has shown that, out of the researched neural network configurations, the following neural 
# network configuration produces the most accurate results

layers = { 
            "number_input_features": 0,   # number of input features will vary, value set elsewhere
            "n_layers": 4, 
            "l0":{"number_hidden_nodes":18,"activation_function":"relu"},
            "l1":{"number_hidden_nodes":9,"activation_function":"relu"},
            "l2":{"number_hidden_nodes":4,"activation_function":"relu"},
            "l3":{"number_hidden_nodes":1,"activation_function":"linear"}
        }

# %%
days_out = '75'

# %%
get_day_df(df,days_out)
# Out:
#              date iso_code     date_75     date_75  total_cases_75  \
# 0      2020-03-13      ABW  2020-05-27  2020-05-27           101.0
# 1      2020-03-20      ABW  2020-06-03  2020-06-03           101.0
# 2      2020-03-24      ABW  2020-06-07  2020-06-07           101.0
# 3      2020-03-25      ABW  2020-06-08  2020-06-08           101.0
# 4      2020-03-26      ABW  2020-06-09  2020-06-09           101.0
# ...           ...      ...         ...         ...             ...
# 31800  2020-08-27      ZWE  2020-11-10         NaN             NaN
# 31801  2020-08-28      ZWE  2020-11-11         NaN             NaN
# 31802  2020-08-29      ZWE  2020-11-12         NaN             NaN
# 31803  2020-08-30      ZWE  2020-11-13         NaN             NaN
# 31804  2020-08-31      ZWE  2020-11-14         NaN             NaN
#
#        total_deaths_75
# 0                  3.0
# 1                  3.0
# 2                  3.0
# 3                  3.0
# 4                  3.0
# ...                ...
# 31800              NaN
# 31801              NaN
# 31802              NaN
# 31803              NaN
# 31804              NaN
#
# [31805 rows x 6 columns]

# %%
# Regression Analysis

# Initialize the list of models
models = []

# Get the features
features = df.columns

# Get the list of future days dataframes
day_df = get_day_df(df,days_out)

# For each of the targets, namely total_cases and total_deaths
for target in ["total_cases","total_deaths"]:

    print(f"{target} %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%>\n\n")

    # Merge the feature dataframe with the day dataframe
    df_n = df.merge(day_df,on=["date","iso_code"],how="left")
    print(df_n.columns)

    # Remove the target columns from merged dataframe
    features = [f for f in features if re.search(target_regex,f) == None]
    features = features[2:]  # Remove date and iso_code

    # Set the number of input features for the neural networks based on the current feature set
    layers["number_input_features"] = len(features)

    # Create an instance of the ml class to start machine learning
    md = ml(df=df_n,
            feature_set=features,
            test_size=0.05,
            title=f"{target} - {days_out} days out",
            target=target,
            period=days_out,
            **layers
           )

    # Train and test the machine learning mode over 100 epochs
    md.train_test(epochs=100)

    # Append the instance of the ml class into the models list
    models.append(md)
# Out:
# total_cases %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%>
#
#
# Index(['date', 'iso_code', 'population', 'population_density', 'median_age',
#        'C1_School closing', 'C2_Workplace closing', 'C3_Cancel public events',
#        'C6_Stay at home requirements', 'C7_Restrictions on internal movement',
#        'C8_International travel controls', 'total_cases', 'total_deaths',
#        'date_75', 'date_75', 'total_cases_75', 'total_deaths_75'],
#       dtype='object')
#
#
#  Training and testing - 75 days ahead
#
#
# target_n = total_cases_75
#
# features = ['population', 'population_density', 'median_age', 'C1_School closing', 'C2_Workplace closing', 'C3_Cancel public events', 'C6_Stay at home requirements', 'C7_Restrictions on internal movement', 'C8_International travel controls', 'total_cases', 'total_deaths']
# population
#
# population_density
#
# median_age
#
# C1_School closing
#
# C2_Workplace closing
#
# C3_Cancel public events
#
# C6_Stay at home requirements
#
# C7_Restrictions on internal movement
#
# C8_International travel controls
#
# total_cases
#
# total_deaths
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 18)                216
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 171
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 40
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 432
# Trainable params: 432
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.4375 - mse: 0.4375
# Epoch 2/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.1550 - mse: 0.1550
# Epoch 3/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.1186 - mse: 0.1186
# Epoch 4/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0887 - mse: 0.0887
# Epoch 5/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0777 - mse: 0.0777
# Epoch 6/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0702 - mse: 0.0702
# Epoch 7/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0638 - mse: 0.0638
# Epoch 8/100
# 582/582 [==============================] - 3s 5ms/step - loss: 0.0589 - mse: 0.0589
# Epoch 9/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0515 - mse: 0.0515
# Epoch 10/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0480 - mse: 0.0480
# Epoch 11/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0442 - mse: 0.0442
# Epoch 12/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0422 - mse: 0.0422
# Epoch 13/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0403 - mse: 0.0403
# Epoch 14/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0383 - mse: 0.0383
# Epoch 15/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0355 - mse: 0.0355
# Epoch 16/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0358 - mse: 0.0358
# Epoch 17/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0301 - mse: 0.0301
# Epoch 18/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0290 - mse: 0.0290
# Epoch 19/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0286 - mse: 0.0286
# Epoch 20/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0288 - mse: 0.0288
# Epoch 21/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0272 - mse: 0.0272
# Epoch 22/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0289 - mse: 0.0289
# Epoch 23/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0228 - mse: 0.0228
# Epoch 24/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0165 - mse: 0.0165
# Epoch 25/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0159 - mse: 0.0159
# Epoch 26/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0154 - mse: 0.0154
# Epoch 27/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0211 - mse: 0.0211
# Epoch 28/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0141 - mse: 0.0141
# Epoch 29/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0137 - mse: 0.0137
# Epoch 30/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0137 - mse: 0.0137
# Epoch 31/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0136 - mse: 0.0136
# Epoch 32/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0141 - mse: 0.0141
# Epoch 33/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0194 - mse: 0.0194
# Epoch 34/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0125 - mse: 0.0125
# Epoch 35/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0138 - mse: 0.0138
# Epoch 36/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0126 - mse: 0.0126
# Epoch 37/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0128 - mse: 0.0128
# Epoch 38/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0126 - mse: 0.0126
# Epoch 39/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0124 - mse: 0.0124
# Epoch 40/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0123 - mse: 0.0123
# Epoch 41/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0120 - mse: 0.0120
# Epoch 42/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0125 - mse: 0.0125
# Epoch 43/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0133 - mse: 0.0133
# Epoch 44/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0115 - mse: 0.0115
# Epoch 45/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0114 - mse: 0.0114
# Epoch 46/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0114 - mse: 0.0114
# Epoch 47/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0130 - mse: 0.0130
# Epoch 48/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0114 - mse: 0.0114
# Epoch 49/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0107 - mse: 0.0107
# Epoch 50/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0109 - mse: 0.0109
# Epoch 51/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0114 - mse: 0.0114
# Epoch 52/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0110 - mse: 0.0110
# Epoch 53/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0116 - mse: 0.0116
# Epoch 54/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0104 - mse: 0.0104
# Epoch 55/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0107 - mse: 0.0107
# Epoch 56/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0118 - mse: 0.0118
# Epoch 57/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0106 - mse: 0.0106
# Epoch 58/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0103 - mse: 0.0103
# Epoch 59/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0102 - mse: 0.0102
# Epoch 60/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0107 - mse: 0.0107
# Epoch 61/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0111 - mse: 0.0111
# Epoch 62/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0098 - mse: 0.0098
# Epoch 63/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0101 - mse: 0.0101
# Epoch 64/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0101 - mse: 0.0101
# Epoch 65/100
# 582/582 [==============================] - 1s 2ms/step - loss: 0.0100 - mse: 0.0100
# Epoch 66/100
# 582/582 [==============================] - 1s 3ms/step - loss: 0.0101 - mse: 0.0101
# Epoch 67/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0101 - mse: 0.0101
# Epoch 68/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0093 - mse: 0.0093
# Epoch 69/100
# 582/582 [==============================] - 1s 2ms/step - loss: 0.0101 - mse: 0.0101
# Epoch 70/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0097 - mse: 0.0097
# Epoch 71/100
# 582/582 [==============================] - 1s 3ms/step - loss: 0.0099 - mse: 0.0099
# Epoch 72/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0100 - mse: 0.0100
# Epoch 73/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0093 - mse: 0.0093
# Epoch 74/100
# 582/582 [==============================] - 1s 2ms/step - loss: 0.0097 - mse: 0.0097
# Epoch 75/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0102 - mse: 0.0102
# Epoch 76/100
# 582/582 [==============================] - 1s 3ms/step - loss: 0.0095 - mse: 0.0095
# Epoch 77/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0101 - mse: 0.0101
# Epoch 78/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0092 - mse: 0.0092
# Epoch 79/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0096 - mse: 0.0096
# Epoch 80/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0097 - mse: 0.0097
# Epoch 81/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0102 - mse: 0.0102
# Epoch 82/100
# 582/582 [==============================] - 1s 3ms/step - loss: 0.0091 - mse: 0.0091
# Epoch 83/100
# 582/582 [==============================] - 3s 4ms/step - loss: 0.0094 - mse: 0.0094
# Epoch 84/100
# 582/582 [==============================] - 3s 5ms/step - loss: 0.0110 - mse: 0.0110
# Epoch 85/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0090 - mse: 0.0090
# Epoch 86/100
# 582/582 [==============================] - 3s 5ms/step - loss: 0.0092 - mse: 0.0092
# Epoch 87/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0090 - mse: 0.0090
# Epoch 88/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0095 - mse: 0.0095
# Epoch 89/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0105 - mse: 0.0105
# Epoch 90/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0091 - mse: 0.0091
# Epoch 91/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0087 - mse: 0.0087
# Epoch 92/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0090 - mse: 0.0090
# Epoch 93/100
# 582/582 [==============================] - 1s 2ms/step - loss: 0.0094 - mse: 0.0094
# Epoch 94/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0091 - mse: 0.0091
# Epoch 95/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0091 - mse: 0.0091
# Epoch 96/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0092 - mse: 0.0092
# Epoch 97/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0093 - mse: 0.0093
# Epoch 98/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0088 - mse: 0.0088
# Epoch 99/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0088 - mse: 0.0088
# Epoch 100/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0095 - mse: 0.0095
# Training r2_score = 0.9910997458033852
# Testing  r2_score = 0.9811013345607241
# total_deaths %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%>
#
#
# Index(['date', 'iso_code', 'population', 'population_density', 'median_age',
#        'C1_School closing', 'C2_Workplace closing', 'C3_Cancel public events',
#        'C6_Stay at home requirements', 'C7_Restrictions on internal movement',
#        'C8_International travel controls', 'total_cases', 'total_deaths',
#        'date_75', 'date_75', 'total_cases_75', 'total_deaths_75'],
#       dtype='object')
#
#
#  Training and testing - 75 days ahead
#
#
# target_n = total_deaths_75
#
# features = ['population', 'population_density', 'median_age', 'C1_School closing', 'C2_Workplace closing', 'C3_Cancel public events', 'C6_Stay at home requirements', 'C7_Restrictions on internal movement', 'C8_International travel controls', 'total_cases', 'total_deaths']
# population
#
# population_density
#
# median_age
#
# C1_School closing
#
# C2_Workplace closing
#
# C3_Cancel public events
#
# C6_Stay at home requirements
#
# C7_Restrictions on internal movement
#
# C8_International travel controls
#
# total_cases
#
# total_deaths
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 18)                216
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 171
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 40
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 432
# Trainable params: 432
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.3747 - mse: 0.3747
# Epoch 2/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.2509 - mse: 0.2509
# Epoch 3/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.2045 - mse: 0.2045
# Epoch 4/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.1761 - mse: 0.1761
# Epoch 5/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.1533 - mse: 0.1533
# Epoch 6/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.1315 - mse: 0.1315
# Epoch 7/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.1132 - mse: 0.1132
# Epoch 8/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0993 - mse: 0.0993
# Epoch 9/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0871 - mse: 0.0871
# Epoch 10/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0787 - mse: 0.0787
# Epoch 11/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0710 - mse: 0.0710
# Epoch 12/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0639 - mse: 0.0639
# Epoch 13/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0565 - mse: 0.0565
# Epoch 14/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0511 - mse: 0.0511
# Epoch 15/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0474 - mse: 0.0474
# Epoch 16/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0425 - mse: 0.0425
# Epoch 17/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0391 - mse: 0.0391
# Epoch 18/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0382 - mse: 0.0382
# Epoch 19/100
# 582/582 [==============================] - 3s 6ms/step - loss: 0.0364 - mse: 0.0364
# Epoch 20/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0346 - mse: 0.0346
# Epoch 21/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0336 - mse: 0.0336
# Epoch 22/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0335 - mse: 0.0335
# Epoch 23/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0321 - mse: 0.0321
# Epoch 24/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0318 - mse: 0.0318
# Epoch 25/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0316 - mse: 0.0316
# Epoch 26/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0296 - mse: 0.0296
# Epoch 27/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0301 - mse: 0.0301
# Epoch 28/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0298 - mse: 0.0298
# Epoch 29/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0302 - mse: 0.0302
# Epoch 30/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0284 - mse: 0.0284
# Epoch 31/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0291 - mse: 0.0291
# Epoch 32/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0291 - mse: 0.0291
# Epoch 33/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0276 - mse: 0.0276
# Epoch 34/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0286 - mse: 0.0286
# Epoch 35/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0277 - mse: 0.0277
# Epoch 36/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0283 - mse: 0.0283
# Epoch 37/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0276 - mse: 0.0276
# Epoch 38/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0270 - mse: 0.0270
# Epoch 39/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0280 - mse: 0.0280
# Epoch 40/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0275 - mse: 0.0275
# Epoch 41/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0285 - mse: 0.0285
# Epoch 42/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0274 - mse: 0.0274
# Epoch 43/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0262 - mse: 0.0262
# Epoch 44/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0272 - mse: 0.0272
# Epoch 45/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0273 - mse: 0.0273
# Epoch 46/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0266 - mse: 0.0266
# Epoch 47/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0260 - mse: 0.0260
# Epoch 48/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0280 - mse: 0.0280
# Epoch 49/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0260 - mse: 0.0260
# Epoch 50/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0262 - mse: 0.0262
# Epoch 51/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0272 - mse: 0.0272
# Epoch 52/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0263 - mse: 0.0263
# Epoch 53/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0263 - mse: 0.0263
# Epoch 54/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0247 - mse: 0.0247
# Epoch 55/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0251 - mse: 0.0251
# Epoch 56/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0281 - mse: 0.0281
# Epoch 57/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0254 - mse: 0.0254
# Epoch 58/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0249 - mse: 0.0249
# Epoch 59/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0274 - mse: 0.0274
# Epoch 60/100
# 582/582 [==============================] - 1s 2ms/step - loss: 0.0250 - mse: 0.0250
# Epoch 61/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0253 - mse: 0.0253
# Epoch 62/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0253 - mse: 0.0253
# Epoch 63/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0255 - mse: 0.0255
# Epoch 64/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0253 - mse: 0.0253
# Epoch 65/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0246 - mse: 0.0246
# Epoch 66/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0271 - mse: 0.0271
# Epoch 67/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0248 - mse: 0.0248
# Epoch 68/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0251 - mse: 0.0251
# Epoch 69/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0254 - mse: 0.0254
# Epoch 70/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0248 - mse: 0.0248
# Epoch 71/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0247 - mse: 0.0247
# Epoch 72/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0247 - mse: 0.0247
# Epoch 73/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0254 - mse: 0.0254
# Epoch 74/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0245 - mse: 0.0245
# Epoch 75/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0238 - mse: 0.0238
# Epoch 76/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0255 - mse: 0.0255
# Epoch 77/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0242 - mse: 0.0242
# Epoch 78/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0243 - mse: 0.0243
# Epoch 79/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0244 - mse: 0.0244
# Epoch 80/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0245 - mse: 0.0245
# Epoch 81/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0251 - mse: 0.0251
# Epoch 82/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0246 - mse: 0.0246
# Epoch 83/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0236 - mse: 0.0236
# Epoch 84/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0244 - mse: 0.0244
# Epoch 85/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0241 - mse: 0.0241
# Epoch 86/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0235 - mse: 0.0235
# Epoch 87/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0238 - mse: 0.0238
# Epoch 88/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0261 - mse: 0.0261
# Epoch 89/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0258 - mse: 0.0258
# Epoch 90/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0245 - mse: 0.0245
# Epoch 91/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0231 - mse: 0.0231
# Epoch 92/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0236 - mse: 0.0236
# Epoch 93/100
# 582/582 [==============================] - 2s 4ms/step - loss: 0.0236 - mse: 0.0236
# Epoch 94/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0249 - mse: 0.0249
# Epoch 95/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0229 - mse: 0.0229
# Epoch 96/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0243 - mse: 0.0243
# Epoch 97/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0237 - mse: 0.0237
# Epoch 98/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0241 - mse: 0.0241
# Epoch 99/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0230 - mse: 0.0230
# Epoch 100/100
# 582/582 [==============================] - 2s 3ms/step - loss: 0.0241 - mse: 0.0241
# Training r2_score = 0.9783097609416989
# Testing  r2_score = 0.9817947455468549

# %%
for md in models:
    df = md.get_df()
    print(df.columns)
# Out:
# Index(['date', 'iso_code', 'population', 'population_density', 'median_age',
#        'C1_School closing', 'C2_Workplace closing', 'C3_Cancel public events',
#        'C6_Stay at home requirements', 'C7_Restrictions on internal movement',
#        'C8_International travel controls', 'total_cases', 'total_deaths',
#        'total_cases_75'],
#       dtype='object')
# Index(['date', 'iso_code', 'population', 'population_density', 'median_age',
#        'C1_School closing', 'C2_Workplace closing', 'C3_Cancel public events',
#        'C6_Stay at home requirements', 'C7_Restrictions on internal movement',
#        'C8_International travel controls', 'total_cases', 'total_deaths',
#        'total_deaths_75'],
#       dtype='object')

# %%
for md in models:
    df = md.get_df()
    model = md.get_model()
    features = md.get_features()
    X_scaler = md.get_X_scaler()
    y_scaler = md.get_y_scaler()
    
    target = md.get_target() + "_" + md.get_period()
    
    iso_codes = df["iso_code"].unique()
    
    for code in iso_codes:
        X = df[df["iso_code"] == code][features]
        
        X_scaled = X_scaler.transform(X)
        y_pred_scaled = model.predict(X_scaled)
        y_pred = y_scaler.inverse_transform(y_pred_scaled)
        
        df_ic = df[df["iso_code"] == code]
        
        time = [str(t) for t in df_ic["date"]]

        x_vals = df_ic["date"].values.tolist()
        y_test = df_ic[target].values.tolist()  
        y_pred_scaled = model.predict(X_scaled).reshape(-1,1).tolist()
        y_pred = [y_scaler.inverse_transform(y) for y in y_pred_scaled]
       
        
        df_c = pd.DataFrame({"Time":x_vals,"Actual":y_test, "Predicted": y_pred})

        plt.figure(figsize=[25,15])
        plt.plot(df_c["Time"], df_c["Actual"], c="Red")
        plt.plot(df_c["Time"], df_c["Predicted"], c="Green")
        
        plt.xlabel("Time")
        plt.ylabel("Actual/Predicted")
        
        plt.title(md.get_title() + "; Country: " + code)
        plt.xticks(rotation=90)
        plt.legend(["Actual","Predicted"])
        
        feature_str = ""
        for feature in features:
            if re.search(gr_regex,feature) != None:
                feature_str = feature_str + "_" + feature[:2]
                
        plt.savefig(f"Resources/graphs/AP_target-{md.get_target()}-features-{feature_str}-period-{md.get_period()}-country-{code}.png")
        plt.close()
