# %%
# import dependencies
from path import Path
import pandas as pd
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from opencage.geocoder import OpenCageGeocode
# %matplotlib inline

# %%
# Import dataset & store into dataframe
merged_covid_df = pd.read_csv("../Resources/merged_covid_FINAL.csv")
merged_covid_df
# Out:
#       primary_key_reaction date_updated iso_code      continent  location  \
# 0            ABW2020-03-13   2020-03-13      ABW  North America     Aruba
# 1            ABW2020-03-19   2020-03-19      ABW  North America     Aruba
# 2            ABW2020-03-20   2020-03-20      ABW  North America     Aruba
# 3            ABW2020-03-21   2020-03-21      ABW  North America     Aruba
# 4            ABW2020-03-22   2020-03-22      ABW  North America     Aruba
# ...                    ...          ...      ...            ...       ...
# 32272        ZWE2020-08-27   2020-08-27      ZWE         Africa  Zimbabwe
# 32273        ZWE2020-08-28   2020-08-28      ZWE         Africa  Zimbabwe
# 32274        ZWE2020-08-29   2020-08-29      ZWE         Africa  Zimbabwe
# 32275        ZWE2020-08-30   2020-08-30      ZWE         Africa  Zimbabwe
# 32276        ZWE2020-08-31   2020-08-31      ZWE         Africa  Zimbabwe
#
#        population  population_density  median_age  new_cases  \
# ...

# %%
#df = merged_covid_df.set_index("continent")
#df

# %%
#new_loc= df.loc["North America"]
#new_loc

# %%
#location_newcases_df = merged_covid_df[["location","new_cases"]]
#location_newcases_df

# %%
# Set location as index
location_newcases_df = pd.DataFrame(merged_covid_df.set_index(["location"])["new_cases"])
location_newcases_df
# Out:
#           new_cases
# location
# Aruba           2.0
# Aruba           0.0
# Aruba           2.0
# Aruba           0.0
# Aruba           0.0
# ...             ...
# Zimbabwe       55.0
# Zimbabwe       41.0
# Zimbabwe       96.0
# Zimbabwe       18.0
# Zimbabwe        6.0
#
# [32277 rows x 1 columns]

# %%
# Average new cases per location from highest to lowest
avg_newcases_df= location_newcases_df.groupby(by=["location"]).mean().sort_values(by="new_cases", ascending =False)
avg_newcases_df[0:10]
# Out:
#                   new_cases
# location
# United States  24578.536885
# Brazil         15829.143443
# India          14841.168033
# Russia          4058.713115
# Peru            3479.387097
# Colombia        3377.433333
# South Africa    3019.594203
# Mexico          2441.971311
# Chile           2277.633333
# Argentina       1976.482759

# %%
# Set location as index- Total deaths
location_totaldeaths_df = pd.DataFrame(merged_covid_df.set_index(["location"])["total_deaths_updated"])
location_totaldeaths_df
# Out:
#           total_deaths_updated
# location
# Aruba                      0.0
# Aruba                      0.0
# Aruba                      0.0
# Aruba                      0.0
# Aruba                      0.0
# ...                        ...
# Zimbabwe                 179.0
# Zimbabwe                 189.0
# Zimbabwe                 195.0
# Zimbabwe                 196.0
# Zimbabwe                 196.0
#
# [32277 rows x 1 columns]

# %%
# Average total deaths per location from highest to lowest
avg_totaldeaths=location_totaldeaths_df.groupby(by=["location"]).mean().sort_values(by="total_deaths_updated",ascending=False)
avg_totaldeaths[0:10]
# Out:
#                 total_deaths_updated
# location
# United States           67881.491803
# Brazil                  30832.647541
# United Kingdom          21253.770492
# Italy                   20114.344262
# France                  16721.889344
# Spain                   16387.670782
# Mexico                  14740.581967
# India                   11351.250000
# Peru                     7883.419355
# Iran                     6854.262295

# %%
# Set location as index- StringencyIndex
location_StringencyIndex_df = pd.DataFrame(merged_covid_df.set_index(["location"])["StringencyIndex_updated"])
location_StringencyIndex_df
# Out:
#           StringencyIndex_updated
# location
# Aruba                        0.00
# Aruba                       33.33
# Aruba                       33.33
# Aruba                       44.44
# Aruba                       44.44
# ...                           ...
# Zimbabwe                    80.56
# Zimbabwe                    80.56
# Zimbabwe                    80.56
# Zimbabwe                    80.56
# Zimbabwe                    80.56
#
# [32277 rows x 1 columns]

# %%
# Average Stringency Index per location from highest to lowest
avg_StringencyIndex=location_StringencyIndex_df.groupby(by=["location"]).mean().sort_values(by="StringencyIndex_updated",ascending=False)
avg_StringencyIndex[0:10]
# Out:
#              StringencyIndex_updated
# location
# Honduras                   96.027135
# Libya                      93.703375
# Guatemala                  92.938706
# El Salvador                92.016265
# Eritrea                    91.560123
# Bolivia                    90.381676
# Palestine                  85.618820
# Venezuela                  83.699706
# Uganda                     83.595215
# Paraguay                   82.296124

# %%
# Set location as Index- Government Response
Govt_Response_df = pd.DataFrame(merged_covid_df.set_index(["location"])["GovernmentResponseIndex_updated"])
Govt_Response_df
# Out:
#           GovernmentResponseIndex_updated
# location
# Aruba                                2.56
# Aruba                               29.49
# Aruba                               29.49
# Aruba                               37.18
# Aruba                               37.18
# ...                                   ...
# Zimbabwe                            66.03
# Zimbabwe                            66.03
# Zimbabwe                            66.03
# Zimbabwe                            66.03
# Zimbabwe                            66.03
#
# [32277 rows x 1 columns]

# %%
# Average Government Response per location from highest to lowest
Govt_Resp_avg=Govt_Response_df.groupby(by=["location"]).mean().sort_values(by="GovernmentResponseIndex_updated",ascending=False)
Govt_Resp_avg[0:10]
# Out:
#              GovernmentResponseIndex_updated
# location
# Honduras                           84.775906
# El Salvador                        83.516446
# Colombia                           78.375556
# Guatemala                          78.078353
# Peru                               76.757043
# Paraguay                           76.639551
# Puerto Rico                        75.652484
# Cape Verde                         75.577744
# Cyprus                             75.372948
# Gabon                              74.523509

# %%
# Set location as index- Containment Index
ContainmentIndex_df = pd.DataFrame(merged_covid_df.set_index(["location"])["ContainmentHealthIndex_updated"])
ContainmentIndex_df
# Out:
#           ContainmentHealthIndex_updated
# location
# Aruba                               3.03
# Aruba                              34.85
# Aruba                              34.85
# Aruba                              43.94
# Aruba                              43.94
# ...                                  ...
# Zimbabwe                           73.48
# Zimbabwe                           73.48
# Zimbabwe                           73.48
# Zimbabwe                           73.48
# Zimbabwe                           73.48
#
# [32277 rows x 1 columns]

# %%
# Average Containment Index per location from Highest to lowest
ContainmentIndex_avg=ContainmentIndex_df.groupby(by=["location"]).mean().sort_values(by="ContainmentHealthIndex_updated",ascending=False)
ContainmentIndex_avg[0:10]
# Out:
#               ContainmentHealthIndex_updated
# location
# El Salvador                        86.704819
# Honduras                           86.138947
# Libya                              84.242062
# Eritrea                            82.440061
# Guatemala                          81.903765
# Kazakhstan                         80.963779
# Colombia                           80.422556
# Paraguay                           78.827360
# Peru                               78.421882
# Saudi Arabia                       78.240391

# %%
# Adding long and lat to dataframe

key = ""  # get api key from:  https://opencagedata.com

geocoder = OpenCageGeocode(key)

query = 'Zimbabwe'  

results = geocoder.geocode(query)

print (results)
# Out:
# [{'annotations': {'DMS': {'lat': "18° 27' 19.78668'' S", 'lng': "29° 44' 48.62904'' E"}, 'MGRS': '35KQV9012157216', 'Maidenhead': 'KH41un90oq', 'Mercator': {'x': 3311403.237, 'y': -2077413.386}, 'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?relation=195272#map=16/-18.45550/29.74684', 'note_url': 'https://www.openstreetmap.org/note/new#map=16/-18.45550/29.74684&layers=N', 'url': 'https://www.openstreetmap.org/?mlat=-18.45550&mlon=29.74684#map=16/-18.45550/29.74684'}, 'UN_M49': {'regions': {'AFRICA': '002', 'EASTERN_AFRICA': '014', 'SUB-SAHARAN_AFRICA': '202', 'WORLD': '001', 'ZW': '716'}, 'statistical_groupings': ['LEDC', 'LLDC']}, 'callingcode': 263, 'flag': '🇿🇼', 'geohash': 'kstphbkbzwhs74ttrszz', 'qibla': 14.36, 'roadinfo': {'drive_on': 'left', 'speed_in': 'km/h'}, 'sun': {'rise': {'apparent': 1599537840, 'astronomical': 1599533460, 'civil': 1599536520, 'nautical': 1599535020}, 'set': {'apparent': 1599580440, 'astronomical': 1599584760, 'civil': 1599581760, 'nautical': 15
# ...

# %%
#lat = results[0]['geometry']['lat']

#lng = results[0]['geometry']['lng']

#print (lat, lng)

# %%
countries= merged_covid_df.location.unique()
countries
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Albania',
#        'United Arab Emirates', 'Argentina', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bolivia', 'Brazil', 'Barbados', 'Brunei',
#        'Bhutan', 'Botswana', 'Central African Republic', 'Canada',
#        'Switzerland', 'Chile', 'China', "Cote d'Ivoire", 'Cameroon',
#        'Democratic Republic of Congo', 'Congo', 'Colombia', 'Cape Verde',
#        'Costa Rica', 'Cuba', 'Cyprus', 'Czech Republic', 'Germany',
#        'Djibouti', 'Denmark', 'Dominican Republic', 'Algeria', 'Ecuador',
#        'Egypt', 'Eritrea', 'Spain', 'Estonia', 'Ethiopia', 'Finland',
#        'Fiji', 'France', 'Gabon', 'United Kingdom', 'Georgia', 'Ghana',
#        'Guinea', 'Gambia', 'Greece', 'Guatemala', 'Guam', 'Guyana',
#        'Hong Kong', 'Honduras', 'Croatia', 'Haiti', 'Hungary',
# ...

# %%
country_lon_lat ={}
for country in countries:
    results = geocoder.geocode(country)
    country_lon_lat[country]={"lat":results[0]['geometry']['lat'], "lon": results[0]['geometry']['lng']}
country_lon_lat
# Out:
# {'Aruba': {'lat': 12.4902998, 'lon': -69.9609842},
#  'Afghanistan': {'lat': 33.7680065, 'lon': 66.2385139},
#  'Angola': {'lat': -11.8775768, 'lon': 17.5691241},
#  'Albania': {'lat': 41.000028, 'lon': 19.9999619},
#  'United Arab Emirates': {'lat': 24.0002488, 'lon': 53.9994829},
#  'Argentina': {'lat': -34.9964963, 'lon': -64.9672817},
#  'Australia': {'lat': -24.7761086, 'lon': 134.755},
#  'Austria': {'lat': 47.2000338, 'lon': 13.199959},
#  'Azerbaijan': {'lat': 40.3936294, 'lon': 47.7872508},
#  'Burundi': {'lat': -3.3634357, 'lon': 29.8870575},
#  'Belgium': {'lat': 50.6402809, 'lon': 4.6667145},
#  'Benin': {'lat': 9.5293472, 'lon': 2.2584408},
#  'Burkina Faso': {'lat': 12.0753083, 'lon': -1.6880314},
#  'Bangladesh': {'lat': 24.4768783, 'lon': 90.2932426},
#  'Bulgaria': {'lat': 42.6073975, 'lon': 25.4856617},
#  'Bahrain': {'lat': 26.1551249, 'lon': 50.5344606},
#  'Bosnia and Herzegovina': {'lat': 44.3053476, 'lon': 17.5961467},
# ...

# %%
country_lon_lat['Aruba']['lat']
# Out:
# 12.4902998

# %%
lat = []
lon = []
for index, row in merged_covid_df.iterrows():
    location = row['location']
    for item in country_lon_lat:
        if location == item:
            lat.append(country_lon_lat[item]['lat'])
            lon.append(country_lon_lat[item]['lon'])
merged_covid_df['lat']=lat
merged_covid_df['lon']=lon
merged_covid_df.tail()
# Out:
#       primary_key_reaction date_updated iso_code continent  location  \
# 32272        ZWE2020-08-27   2020-08-27      ZWE    Africa  Zimbabwe
# 32273        ZWE2020-08-28   2020-08-28      ZWE    Africa  Zimbabwe
# 32274        ZWE2020-08-29   2020-08-29      ZWE    Africa  Zimbabwe
# 32275        ZWE2020-08-30   2020-08-30      ZWE    Africa  Zimbabwe
# 32276        ZWE2020-08-31   2020-08-31      ZWE    Africa  Zimbabwe
#
#        population  population_density  median_age  new_cases  \
# 32272  14862927.0              42.729        19.6       55.0
# 32273  14862927.0              42.729        19.6       41.0
# 32274  14862927.0              42.729        19.6       96.0
# 32275  14862927.0              42.729        19.6       18.0
# 32276  14862927.0              42.729        19.6        6.0
#
#        percentage_of_Pop_New_Cases  ...  percentage_change_stringency  \
# 32272                     0.000370  ...                           0.0
# ...

# %%
merged_covid_df
# Out:
#       primary_key_reaction date_updated iso_code      continent  location  \
# 0            ABW2020-03-13   2020-03-13      ABW  North America     Aruba
# 1            ABW2020-03-19   2020-03-19      ABW  North America     Aruba
# 2            ABW2020-03-20   2020-03-20      ABW  North America     Aruba
# 3            ABW2020-03-21   2020-03-21      ABW  North America     Aruba
# 4            ABW2020-03-22   2020-03-22      ABW  North America     Aruba
# ...                    ...          ...      ...            ...       ...
# 32272        ZWE2020-08-27   2020-08-27      ZWE         Africa  Zimbabwe
# 32273        ZWE2020-08-28   2020-08-28      ZWE         Africa  Zimbabwe
# 32274        ZWE2020-08-29   2020-08-29      ZWE         Africa  Zimbabwe
# 32275        ZWE2020-08-30   2020-08-30      ZWE         Africa  Zimbabwe
# 32276        ZWE2020-08-31   2020-08-31      ZWE         Africa  Zimbabwe
#
#        population  population_density  median_age  new_cases  \
# ...

# %%
# Export all three DataFrames to .csv
merged_covid_df.to_csv('../Resources/merged_covid_lon_lat.csv', index=False)
